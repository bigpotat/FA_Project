# %%
#import the required libraries here
from pandas_datareader import data
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from scipy.stats import norm
from matplotlib.ticker import FuncFormatter

import pyfolio as pf

# %matplotlib inline
# Out:
# C:\Users\SiYu\anaconda3\lib\site-packages\pyfolio\pos.py:26: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   warnings.warn(

# %%
tickers = ['FSLY','IMMR', 'FB', 'U','NVDA','AAPL', 'MSFT',"METV"]

start_date = '2021-07-01'
end_date = '2022-03-01'

panel_data = data.DataReader(tickers,'yahoo', start_date, end_date)
panel_data = panel_data.loc['2021-01-01' : '2021-12-31']
data = panel_data[['Close', 'Adj Close']]
data.head()
# Out:
# Attributes      Close                                                        \
# Symbols          FSLY  IMMR          FB           U        NVDA        AAPL
# Date
# 2021-06-30  59.599998  8.77  347.709991  109.830002  200.024994  136.960007
# 2021-07-01  58.020000  8.49  354.390015  105.839996  202.119995  137.270004
# 2021-07-02  56.470001  8.46  354.700012  106.089996  204.869995  139.960007
# 2021-07-06  56.860001  8.22  352.779999  106.650002  206.985001  142.020004
# 2021-07-07  54.369999  8.23  350.489990  104.489998  203.717499  144.570007
#
# Attributes                     Adj Close                                \
# Symbols           MSFT   METV       FSLY  IMMR          FB           U
# Date
# 2021-06-30  270.899994  15.12  59.599998  8.77  347.709991  109.830002
# 2021-07-01  271.600006  14.89  58.020000  8.49  354.390015  105.839996
# 2021-07-02  277.649994  15.00  56.470001  8.46  354.700012  106.089996
# 2021-07-06  277.660004  15.01  56.860001  8.22  352.779999  106.650002
# 2021-07-07  279.929993  14.89  54.369999  8.23  350.489990  104.489998
#
# Attributes
# Symbols           NVDA        AAPL        MSFT   METV
# Date
# 2021-06-30  199.931183  136.382065  269.331726  15.12
# 2021-07-01  202.025208  136.690750  270.027679  14.89
# 2021-07-02  204.773911  139.369400  276.042633  15.00
# 2021-07-06  206.887924  141.420700  276.052582  15.01
# 2021-07-07  203.621964  143.959946  278.309448  14.89

# %%
data.tail()
# Out:
# Attributes      Close                                                        \
# Symbols          FSLY  IMMR          FB           U        NVDA        AAPL
# Date
# 2021-12-27  37.750000  6.05  346.179993  148.009995  309.450012  180.330002
# 2021-12-28  36.259998  5.87  346.220001  143.520004  303.220001  179.289993
# 2021-12-29  35.090000  5.80  342.940002  144.550003  300.010010  179.380005
# 2021-12-30  37.230000  5.85  344.359985  145.919998  295.859985  178.199997
# 2021-12-31  35.450001  5.71  336.350006  142.990005  294.109985  177.570007
#
# Attributes                     Adj Close                                \
# Symbols           MSFT   METV       FSLY  IMMR          FB           U
# Date
# 2021-12-27  342.450012  15.60  37.750000  6.05  346.179993  148.009995
# 2021-12-28  341.250000  15.37  36.259998  5.87  346.220001  143.520004
# 2021-12-29  341.950012  15.25  35.090000  5.80  342.940002  144.550003
# 2021-12-30  339.320007  15.31  37.230000  5.85  344.359985  145.919998
# 2021-12-31  336.320007  15.18  35.450001  5.71  336.350006  142.990005
#
# Attributes
# Symbols           NVDA        AAPL        MSFT   METV
# Date
# 2021-12-27  309.397308  180.100540  341.743378  15.60
# 2021-12-28  303.168335  179.061859  340.545837  15.37
# 2021-12-29  299.958893  179.151749  341.244415  15.25
# 2021-12-30  295.809601  177.973251  338.619843  15.31
# 2021-12-31  294.059875  177.344055  335.626038  15.18

# %%
close_data = panel_data['Close']
adj_close_data = panel_data['Adj Close']

# %%
## Check for null values 
close_data.isnull().sum()
adj_close_data.isnull().sum()
# Out:
# Symbols
# FSLY    0
# IMMR    0
# FB      0
# U       0
# NVDA    0
# AAPL    0
# MSFT    0
# METV    0
# dtype: int64

# %%
close_data.count()
# Out:
# Symbols
# FSLY    129
# IMMR    129
# FB      129
# U       129
# NVDA    129
# AAPL    129
# MSFT    129
# METV    129
# dtype: int64

# %%
### Calculate the adj close returned series
return_series_adj = (adj_close_data.pct_change()+ 1).cumprod() - 1
return_series_adj.tail(1)*100
# Out:
# Symbols          FSLY       IMMR        FB          U       NVDA       AAPL  \
# Date
# 2021-12-31 -40.520131 -34.891679 -3.267086  30.192118  47.080546  30.034734
#
# Symbols          MSFT      METV
# Date
# 2021-12-31  24.614371  0.396828

# %%
return_series_adj.plot(figsize=(16,9))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
ax1 = return_series_adj.plot(figsize=(16,9))
#This sets the axis to percentage scale
ax1.yaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:.0%}'.format(y)))

# %%
### Check for annualised return 
annualized_return = (1+return_series_adj.tail(1))**(1/(1/2))-1
annualized_return
# Out:
# Symbols         FSLY      IMMR        FB         U      NVDA      AAPL  \
# Date
# 2021-12-31 -0.646215 -0.576091 -0.064274  0.694999  1.163269  0.690903
#
# Symbols         MSFT      METV
# Date
# 2021-12-31  0.552874  0.007952

# %%
annualized_return.plot.bar(rot=0, figsize=(16,9))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
annualized_return = annualized_return.squeeze()
# annualized_return.sort_values(ascending=True).plot.bar(rot=0, figsize=(16,9))

ax = annualized_return.sort_values(ascending=True).plot.bar(rot=0, figsize=(16,9))
type(ax)  # matplotlib.axes._subplots.AxesSubplot

# manipulate
vals = ax.get_yticks()
ax.set_yticklabels(['{:,.2%}'.format(x) for x in vals])
# Out:
# C:\Users\SiYu\AppData\Local\Temp/ipykernel_10688/863718015.py:9: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['{:,.2%}'.format(x) for x in vals])
# [Text(0, -0.75, '-75.00%'),
#  Text(0, -0.5, '-50.00%'),
#  Text(0, -0.25, '-25.00%'),
#  Text(0, 0.0, '0.00%'),
#  Text(0, 0.25, '25.00%'),
#  Text(0, 0.5, '50.00%'),
#  Text(0, 0.75, '75.00%'),
#  Text(0, 1.0, '100.00%'),
#  Text(0, 1.25, '125.00%'),
#  Text(0, 1.5, '150.00%')]

# %%
### Find Corr between these stocks
return_series_close = (close_data.pct_change()+ 1).cumprod() - 1
# return_series_close.plot(figsize=(16,9))
return_series_close.corr()
# Out:
# Symbols      FSLY      IMMR        FB         U      NVDA      AAPL      MSFT  \
# Symbols
# FSLY     1.000000  0.758933  0.149105 -0.197366 -0.298011 -0.504765 -0.298211
# IMMR     0.758933  1.000000  0.373492 -0.442718 -0.605199 -0.706019 -0.552908
# FB       0.149105  0.373492  1.000000 -0.422991 -0.486578 -0.259623 -0.459541
# U       -0.197366 -0.442718 -0.422991  1.000000  0.823507  0.388195  0.838717
# NVDA    -0.298011 -0.605199 -0.486578  0.823507  1.000000  0.751314  0.945436
# AAPL    -0.504765 -0.706019 -0.259623  0.388195  0.751314  1.000000  0.742984
# MSFT    -0.298211 -0.552908 -0.459541  0.838717  0.945436  0.742984  1.000000
# METV     0.109466 -0.222922 -0.182229  0.822390  0.830791  0.456147  0.790530
#
# Symbols      METV
# Symbols
# FSLY     0.109466
# IMMR    -0.222922
# FB      -0.182229
# U        0.822390
# NVDA     0.830791
# AAPL     0.456147
# MSFT     0.790530
# METV     1.000000

# %%
import seaborn as sns
dataplot = sns.heatmap(return_series_close.corr(), cmap="YlGnBu")

# %%
### Volatility
ahv = np.sqrt(np.log(close_data / close_data.shift(1)).var()) * np.sqrt(252)
ahv
# Out:
# Symbols
# FSLY    0.603225
# IMMR    0.670091
# FB      0.285605
# U       0.557605
# NVDA    0.460791
# AAPL    0.223441
# MSFT    0.198213
# METV    0.225692
# dtype: float64

# %%
# ahv.sort_values(ascending=True).plot.bar(rot=0, figsize=(16,9))

ax = ahv.sort_values(ascending=True).plot.bar(rot=0, figsize=(16,9))


# manipulate
vals = ax.get_yticks()
ax.set_yticklabels(['{:,.2%}'.format(x) for x in vals])
# Out:
# C:\Users\SiYu\AppData\Local\Temp/ipykernel_10688/3817654803.py:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['{:,.2%}'.format(x) for x in vals])
# [Text(0, 0.0, '0.00%'),
#  Text(0, 0.1, '10.00%'),
#  Text(0, 0.2, '20.00%'),
#  Text(0, 0.30000000000000004, '30.00%'),
#  Text(0, 0.4, '40.00%'),
#  Text(0, 0.5, '50.00%'),
#  Text(0, 0.6000000000000001, '60.00%'),
#  Text(0, 0.7000000000000001, '70.00%'),
#  Text(0, 0.8, '80.00%')]

# %%
risk_free_ann_ret_rate = 0.01

returns_ts = adj_close_data.pct_change().dropna()
avg_daily_ret = returns_ts.mean()

returns_ts['RiskFree_Rate'] = risk_free_ann_ret_rate/252
avg_rf_ret = returns_ts['RiskFree_Rate'].mean()

#Add the excess return columns for each ETF
returns_ts['Excess_ret_FSLY'] = returns_ts["FSLY"] - returns_ts['RiskFree_Rate']
returns_ts['Excess_ret_IMMR'] = returns_ts["IMMR"] - returns_ts['RiskFree_Rate']
returns_ts['Excess_ret_FB'] = returns_ts["FB"] - returns_ts['RiskFree_Rate']
returns_ts['Excess_ret_U'] = returns_ts["U"] - returns_ts['RiskFree_Rate']
returns_ts['Excess_ret_NVDA'] = returns_ts["NVDA"] - returns_ts['RiskFree_Rate']
returns_ts['Excess_ret_AAPL'] = returns_ts["AAPL"] - returns_ts['RiskFree_Rate']
returns_ts['Excess_ret_MSFT'] = returns_ts["MSFT"] - returns_ts['RiskFree_Rate']
returns_ts['Excess_ret_METV'] = returns_ts["METV"] - returns_ts['RiskFree_Rate']

# %%
#calculate sharpe ratio

sharpe_FSLY = ((avg_daily_ret['FSLY'] - avg_rf_ret) /returns_ts['Excess_ret_FSLY'].std())*np.sqrt(252)
print("Sharpe Ratio FSLY :\n", sharpe_FSLY.round(2))
sharpe_IMMR = ((avg_daily_ret['IMMR'] - avg_rf_ret) /returns_ts['Excess_ret_IMMR'].std())*np.sqrt(252)
print("Sharpe Ratio IMMR :\n" , sharpe_IMMR.round(2))
sharpe_FB = ((avg_daily_ret['FB'] - avg_rf_ret) /returns_ts['Excess_ret_FB'].std())*np.sqrt(252)
print("Sharpe Ratio FB :\n" , sharpe_FB.round(2))
sharpe_U = ((avg_daily_ret['U'] - avg_rf_ret) /returns_ts['Excess_ret_U'].std())*np.sqrt(252)
print("Sharpe Ratio U :\n", sharpe_U.round(2))
sharpe_NVDA = ((avg_daily_ret['NVDA'] - avg_rf_ret) /returns_ts['Excess_ret_NVDA'].std())*np.sqrt(252)
print("Sharpe Ratio NVDA :\n" , sharpe_NVDA.round(2))
sharpe_AAPL = ((avg_daily_ret['AAPL'] - avg_rf_ret) /returns_ts['Excess_ret_AAPL'].std())*np.sqrt(252)
print("Sharpe Ratio AAPL :\n" , sharpe_AAPL.round(2))
sharpe_MSFT = ((avg_daily_ret['MSFT'] - avg_rf_ret) /returns_ts['Excess_ret_MSFT'].std())*np.sqrt(252)
print("Sharpe Ratio MSFT :\n" , sharpe_MSFT.round(2))

sharpe_METV = ((avg_daily_ret['METV'] - avg_rf_ret) /returns_ts['Excess_ret_METV'].std())*np.sqrt(252)
print("Sharpe Ratio METV :\n" , sharpe_METV.round(2))
# Out:
# Sharpe Ratio FSLY :
#  -1.42
# Sharpe Ratio IMMR :
#  -0.98
# Sharpe Ratio FB :
#  -0.12
# Sharpe Ratio U :
#  1.19
# Sharpe Ratio NVDA :
#  1.84
# Sharpe Ratio AAPL :
#  2.38
# Sharpe Ratio MSFT :
#  2.23
# Sharpe Ratio METV :
#  0.1

# %%
flattened_data = pd.read_csv('flattened_data.csv')

# %%
#Install panda profiling 
'''
import sys
# !{sys.executable} -m pip install -U pandas-profiling[notebook]
# !jupyter nbextension enable --py widgetsnbextension
'''
# Out:
# '\nimport sys\n!{sys.executable} -m pip install -U pandas-profiling[notebook]\n!jupyter nbextension enable --py widgetsnbextension\n'

# %%
from pandas_profiling import ProfileReport
prof = ProfileReport(flattened_data)
prof.to_file(output_file='output.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
#Write to csv 
adj_close_data.to_csv("Adj_close.csv", sep=',', encoding='utf-8')

# %%
adj_close_prof = ProfileReport(adj_close_data)
adj_close_prof.to_file(output_file='Adj_close_output.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
import copy
TechIndicator = copy.deepcopy(data)

# %%
def rsi(values):
    up = values[values>0].mean()
    down = -1*values[values<0].mean()
    return 100 * up / (up + down)

# %%
RSI=TechIndicator["Close"]
tech_list=RSI.columns.to_list()
tech_list
# Out:
# ['FSLY', 'IMMR', 'FB', 'U', 'NVDA', 'AAPL', 'MSFT', 'METV']

# %%
RSI
# Out:
# Symbols          FSLY  IMMR          FB           U        NVDA        AAPL  \
# Date
# 2021-06-30  59.599998  8.77  347.709991  109.830002  200.024994  136.960007
# 2021-07-01  58.020000  8.49  354.390015  105.839996  202.119995  137.270004
# 2021-07-02  56.470001  8.46  354.700012  106.089996  204.869995  139.960007
# 2021-07-06  56.860001  8.22  352.779999  106.650002  206.985001  142.020004
# 2021-07-07  54.369999  8.23  350.489990  104.489998  203.717499  144.570007
# ...               ...   ...         ...         ...         ...         ...
# 2021-12-27  37.750000  6.05  346.179993  148.009995  309.450012  180.330002
# 2021-12-28  36.259998  5.87  346.220001  143.520004  303.220001  179.289993
# 2021-12-29  35.090000  5.80  342.940002  144.550003  300.010010  179.380005
# 2021-12-30  37.230000  5.85  344.359985  145.919998  295.859985  178.199997
# 2021-12-31  35.450001  5.71  336.350006  142.990005  294.109985  177.570007
#
# Symbols           MSFT   METV
# Date
# 2021-06-30  270.899994  15.12
# 2021-07-01  271.600006  14.89
# 2021-07-02  277.649994  15.00
# 2021-07-06  277.660004  15.01
# 2021-07-07  279.929993  14.89
# ...                ...    ...
# 2021-12-27  342.450012  15.60
# 2021-12-28  341.250000  15.37
# 2021-12-29  341.950012  15.25
# 2021-12-30  339.320007  15.31
# 2021-12-31  336.320007  15.18
#
# [129 rows x 8 columns]

# %%
for stock in tech_list:
    momentum_1D=stock+"|Momentum_1D"
    RSI_14D=stock+"|RSI_14D"
    RSI[momentum_1D] = (RSI[stock]-RSI[stock].shift(1)).fillna(0)
    RSI[RSI_14D] = RSI[momentum_1D].rolling(center=False, window=14).apply(rsi).fillna(0)
# Out:
# C:\Users\SiYu\AppData\Local\Temp/ipykernel_10688/3767238250.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RSI[momentum_1D] = (RSI[stock]-RSI[stock].shift(1)).fillna(0)
# C:\Users\SiYu\AppData\Local\Temp/ipykernel_10688/3767238250.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RSI[RSI_14D] = RSI[momentum_1D].rolling(center=False, window=14).apply(rsi).fillna(0)

# %%
RSI.iloc[13,:]
# Out:
# Symbols
# FSLY                 51.500000
# IMMR                  7.760000
# FB                  341.660004
# U                   100.160004
# NVDA                186.119995
# AAPL                146.149994
# MSFT                279.320007
# METV                 14.460000
# FSLY|Momentum_1D      0.290001
# FSLY|RSI_14D         30.297856
# IMMR|Momentum_1D      0.120000
# IMMR|RSI_14D         31.599220
# FB|Momentum_1D        4.709991
# FB|RSI_14D           54.889654
# U|Momentum_1D         1.930000
# U|RSI_14D            31.518035
# NVDA|Momentum_1D     -1.677505
# NVDA|RSI_14D         40.380385
# AAPL|Momentum_1D      3.699997
# AAPL|RSI_14D         56.327777
# MSFT|Momentum_1D      2.309998
# MSFT|RSI_14D         55.253151
# METV|Momentum_1D      0.150000
# METV|RSI_14D         39.957475
# Name: 2021-07-20 00:00:00, dtype: float64

# %%
#Sentiment Analysis
# Import libraries
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import os
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# NLTK VADER for sentiment analysis
from nltk.sentiment.vader import SentimentIntensityAnalyzer

finwiz_url = 'https://finviz.com/quote.ashx?t='

# %%
news_tables = {}

for ticker in tech_list:
    url = finwiz_url + ticker
    req = Request(url=url,headers={'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:20.0) Gecko/20100101 Firefox/20.0'}) 
    response = urlopen(req)    
    # Read the contents of the file into 'html'
    html = BeautifulSoup(response)
    # Find 'news-table' in the Soup and load it into 'news_table'
    news_table = html.find(id='news-table')
    # Add the table to our dictionary
    news_tables[ticker] = news_table

# %%
news_tables
# Out:
# {'FSLY': <table border="0" cellpadding="1" cellspacing="0" class="fullview-news-outer" id="news-table" width="100%">
#  <tr><td align="right" style="white-space:nowrap" width="130">Mar-23-22 06:15PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/fastly-fsly-stock-moves-0-221510051.html" target="_blank">Fastly (FSLY) Stock Moves -0.98%: What You Should Know</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Zacks</span></div></div></td></tr>
#  <tr><td align="right" width="130">02:23PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/fastly-only-vendor-named-gartner-182300666.html" target="_blank">Fastly Only Vendor Named Gartner Peer Insights Customers Choice for Web Application and API Protection for Four Consecutive Years</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Business Wire</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Mar-22-22 08:01AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/cloudflare-doesn-t-offer-investors-120146027.html" target="_blank">Cloudflare Doesnt Offer Investors Security at This Price</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> InvestorPlace</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Mar-21-22 10:58AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/adobes-adbe-q1-earnings-gain-145802620.html" target="_blank">Will Adobe's (ADBE) Q1 Earnings Gain From Digital Media?</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Zacks</span></div></div></td></tr>
#  <tr><td align="right" width="130">05:06AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/03/21/10-stocks-ive-bought-during-the-market-sell-off/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">10 Stocks I've Bought During the Market Sell-Off</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Mar-20-22 05:06AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/03/20/3-tech-stocks-turn-200000-to-1-million-in-8-years/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">3 Tech Stocks That Can Turn $200,000 Into $1 Million in 8 Years (or Less)</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Mar-17-22 09:00AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/fastly-named-leader-idc-marketscape-130000640.html" target="_blank">Fastly Named a Leader in IDC MarketScape for Worldwide Commercial CDN 2022 Vendor Assessment</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Business Wire</span> <span class="body-table-news-gain">+6.29%</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Mar-14-22 05:06AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/03/14/2-metaverse-stocks-to-buy-1-to-avoid-like-plague/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">2 Metaverse Stocks to Buy Hand Over Fist and 1 to Avoid Like the Plague</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Mar-12-22 07:00AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/03/12/zendesk-could-10x-customer-return-or-fall-the-way/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">Zendesk Could 10X Customer Return -- or Fall the Way of Fastly, New Relic</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Mar-03-22 03:21PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/03/03/why-shares-of-pinterest-fastly-and-block-slipped-o/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">Why Shares of Pinterest, Fastly, and Block Slipped on Thursday</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span> <span class="body-table-news-loss">-7.41%</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Mar-02-22 03:07PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/03/02/why-fastly-stock-tanked-351-in-february/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">Why Fastly Stock Tanked 35.1% in February</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
#  <tr><td align="right" width="130">09:00AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/fastly-accelerates-edge-adoption-compute-140000052.html" target="_blank">Fastly Accelerates Edge Adoption with New <span class="__cf_email__" data-cfemail="aeedc1c3dedbdacbeeebcac9cb">[email protected]</span> Partner Ecosystem</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Business Wire</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Feb-28-22 05:00PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/fastly-present-morgan-stanley-technology-220000772.html" target="_blank">Fastly to Present at the Morgan Stanley Technology, Media, and Telecom Conference</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Business Wire</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Feb-24-22 11:07AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/02/24/why-nvidia-apple-and-fastly-stock-are-all-falling/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">Why Nvidia, Apple, and Fastly Stocks Are All Falling Today</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span> <span class="body-table-news-gain">+6.29%</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Feb-23-22 01:04PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/02/23/why-lemonade-fastly-and-block-are-falling-today/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">Why Lemonade, Fastly, and Block Are Falling Today</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span> <span class="body-table-news-loss">-6.81%</span></div></div></td></tr>
#  <tr><td align="right" width="130">11:00AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/raymond-james-2-strong-buy-160025230.html" target="_blank">Raymond James: 2 Strong Buy Stocks That Could Climb Over 50%</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> TipRanks</span></div></div></td></tr>
#  <tr><td align="right" width="130">10:00AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/heres-why-fastly-fsly-poised-150003638.html" target="_blank">Here's Why Fastly (FSLY) is Poised for a Turnaround After Losing 28.6% in 4 Weeks</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Zacks</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Feb-20-22 03:22AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/billionaire-ken-griffin-loading-10-082204467.html" target="_blank">Billionaire Ken Griffin Is Loading Up on These 10 Stocks</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Insider Monkey</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Feb-18-22 05:55PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/02/18/why-fastly-stock-fell-on-friday/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">Why Fastly Stock Fell Again Today Despite an Analyst Upgrade</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
#  <tr><td align="right" width="130">11:19AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/raymond-james-turns-bullish-fastly-161923343.html" target="_blank">Raymond James Turns Bullish On Fastly, Cites Recent Pullback As 'Overreaction'</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Benzinga</span></div></div></td></tr>
#  <tr><td align="right" width="130">08:40AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/02/18/4-red-flags-for-fastly-future/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">4 Red Flags for Fastly's Future</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
#  <tr><td align="right" width="130">02:51AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/roku-draftkings-shake-shack-fall-075120727.html" target="_blank">Roku, DraftKings Shake Shack Fall Premarket; Livent, Fastly Rise</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Investing.com</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Feb-17-22 01:01PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/3-stocks-buy-while-markets-180110767.html" target="_blank">3 Stocks to Buy While Markets Deal With an Enemy Fed</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> InvestorPlace</span> <span class="body-table-news-loss">-33.63%</span></div></div></td></tr>
#  <tr><td align="right" width="130">11:58AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.barrons.com/articles/fastly-stock-earnings-guidance-51645117054?siteid=yhoof2" target="_blank">Fastly Stock Is Tumbling. The Companys Guidance May Be Too Conservative.</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Barrons.com</span></div></div></td></tr>
#  <tr><td align="right" width="130">10:50AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/02/17/heres-why-fastly-is-plunging-by-another-30-today/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">Here's Why Fastly Is Plunging by Another 30% Today</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
#  <tr><td align="right" width="130">10:18AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/video/stocks-palantir-tumbles-fastly-plunges-151821709.html" target="_blank">Palantir stock and Fastly stock plunge on missed earnings expectations</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Yahoo Finance Video</span></div></div></td></tr>
#  <tr><td align="right" width="130">10:13AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/fastly-fsly-reports-q4-loss-151303135.html" target="_blank">Fastly (FSLY) Reports Q4 Loss, Tops Revenue Estimates</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Zacks</span></div></div></td></tr>
#  <tr><td align="right" width="130">09:28AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.barrons.com/articles/fastly-stock-price-earnings-guidance-51645055274?siteid=yhoof2" target="_blank">Fastly Stock Drops 30% After Earnings. Whats Spooking Investors.</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Barrons.com</span></div></div></td></tr>
#  <tr><td align="right" width="130">08:33AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/02/17/why-these-2-cloud-stocks-are-getting-pummeled-thur/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">Why These 2 Cloud Stocks Are Getting Pummeled Thursday</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
#  <tr><td align="right" width="130">07:04AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/fastly-tumbles-2022-loss-seen-120425699.html" target="_blank">Fastly Tumbles as 2022 Loss Seen Wider, Brokerages Cut Targets</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Investing.com</span></div></div></td></tr>
#  <tr><td align="right" width="130">06:34AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.barrons.com/articles/fastly-stock-earnings-51645055274?siteid=yhoof2" target="_blank">Fastly Earnings Beat Estimates. Why the Stock Is Tumbling.</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Barrons.com</span></div></div></td></tr>
#  <tr><td align="right" width="130">03:00AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/walmart-doordash-cisco-rise-premarket-080007810.html" target="_blank">Walmart, DoorDash, Cisco Rise Premarket; Fastly, TripAdvisor Slump</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Investing.com</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Feb-16-22 06:47PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.barrons.com/articles/fastly-shares-swoon-as-guidance-misses-estimates-51645055274?siteid=yhoof2" target="_blank">Fastly Shares Swoon as Guidance Misses Estimates</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Barrons.com</span></div></div></td></tr>
#  <tr><td align="right" width="130">06:15PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/fastly-fsly-reports-q4-loss-231511617.html" target="_blank">Fastly (FSLY) Reports Q4 Loss, Tops Revenue Estimates</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Zacks</span></div></div></td></tr>
#  <tr><td align="right" width="130">05:46PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/02/16/fastly-stock-is-sliding-after-the-companys-earning/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">Fastly Stock Is Sliding After the Company's Earnings</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
#  <tr><td align="right" width="130">04:43PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.marketwatch.com/story/fastly-stock-plunges-after-forecast-calls-for-bigger-2022-growth-slowdown-than-expected-11645047782?siteid=yhoof2" target="_blank">Fastly stock plunges after forecast calls for bigger 2022 growth slowdown than expected</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> MarketWatch</span></div></div></td></tr>
#  <tr><td align="right" width="130">04:05PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/fastly-announces-fourth-quarter-full-210500917.html" target="_blank">Fastly Announces Fourth Quarter and Full Year 2021 Financial Results</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Business Wire</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Feb-15-22 08:38AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/02/15/fastly-vs-twilio-which-is-the-best-buy-now/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">Fastly vs. Twilio: Which Is the Best Buy Now?</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
#  <tr><td align="right" width="130">06:05AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/02/15/2-growth-stocks-reporting-earnings-this-week/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">2 Growth Stocks Reporting Earnings This Week</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Feb-14-22 12:27PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/shopify-shop-report-q4-earnings-172705691.html" target="_blank">Shopify (SHOP) to Report Q4 Earnings: What's in the Cards?</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Zacks</span></div></div></td></tr>
#  <tr><td align="right" width="130">11:50AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/cisco-systems-csco-report-q2-165004378.html" target="_blank">Cisco Systems (CSCO) to Report Q2 Earnings: Factors to Note</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Zacks</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Feb-11-22 05:26PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/02/11/heres-another-reason-why-shopify-is-an-unstoppable/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">Here's Another Reason Why Shopify Is an Unstoppable E-Commerce Stock to Buy in 2022</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
#  <tr><td align="right" width="130">01:56PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/why-fastly-fsly-might-surprise-185606152.html" target="_blank">Why Fastly (FSLY) Might Surprise This Earnings Season</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Zacks</span></div></div></td></tr>
#  <tr><td align="right" width="130">01:10PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/ipg-photonics-ipgp-post-q4-181006902.html" target="_blank">IPG Photonics (IPGP) to Post Q4 Earnings: What to Expect?</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Zacks</span></div></div></td></tr>
#  <tr><td align="right" width="130">12:14PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/fastly-fsly-report-q4-earnings-171405744.html" target="_blank">Fastly (FSLY) to Report Q4 Earnings: What's in the Cards?</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Zacks</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Feb-09-22 03:01PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/fastly-fsly-expected-beat-earnings-200108802.html" target="_blank">Fastly (FSLY) Expected to Beat Earnings Estimates: Can the Stock Move Higher?</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Zacks</span> <span class="body-table-news-gain">+5.58%</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Feb-08-22 04:39PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/02/08/are-these-bargain-stocks-worth-a-second-look-right/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">Are These Bargain Stocks Worth a Second Look Right Now?</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
#  <tr><td align="right" width="130">11:35AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.marketwatch.com/story/these-15-stocks-rose-100-or-more-during-the-pandemic-but-theyve-since-been-crushed-is-it-now-time-to-buy-11644338117?siteid=yhoof2" target="_blank">These 15 stocks rose 100% or more during the pandemic, but theyve since been crushed. Is it now time to buy?</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> MarketWatch</span></div></div></td></tr>
#  <tr><td align="right" width="130">09:00AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/fastly-launches-edge-deployment-option-140000584.html" target="_blank">Fastly Launches Edge Deployment Option for Industry's First and Only Unified WAF</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Business Wire</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Feb-07-22 06:15PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/fastly-fsly-gains-market-dips-231511142.html" target="_blank">Fastly (FSLY) Gains As Market Dips: What You Should Know</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Zacks</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Feb-03-22 01:38PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/longitude-cayman-ltd-buys-tesla-183835163.html" target="_blank">Longitude (Cayman) Ltd. Buys Tesla Inc, Meta Platforms Inc, PayPal Holdings Inc, Sells Invitae ...</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> GuruFocus.com</span> <span class="body-table-news-loss">-6.65%</span></div></div></td></tr>
#  <tr><td align="right" width="130">11:33AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/onsemi-report-q4-earnings-whats-163304184.html" target="_blank">onsemi (ON) to Report Q4 Earnings: What's in the Cards?</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Zacks</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Feb-02-22 01:38PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/derbend-asset-management-buys-global-183825842.html" target="_blank">Derbend Asset Management Buys Global X U.S. ...</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> GuruFocus.com</span> <span class="body-table-news-loss">-6.23%</span></div></div></td></tr>
#  <tr><td align="right" width="130">12:22PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/02/02/why-pinterest-fastly-and-teladoc-stocks-fell-sharp/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">Why Pinterest, Fastly, and Teladoc Stocks Fell Sharply on Wednesday</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Feb-01-22 06:15PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/fastly-fsly-outpaces-stock-market-231511133.html" target="_blank">Fastly (FSLY) Outpaces Stock Market Gains: What You Should Know</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Zacks</span></div></div></td></tr>
#  <tr><td align="right" width="130">11:43AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/skyworks-swks-report-q1-earnings-164304249.html" target="_blank">Skyworks (SWKS) to Report Q1 Earnings: What's in the Cards?</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Zacks</span></div></div></td></tr>
#  <tr><td align="right" width="130">10:03AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/microchip-mchp-report-q3-earnings-150303006.html" target="_blank">Microchip (MCHP) to Report Q3 Earnings: What's in the Cards?</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Zacks</span></div></div></td></tr>
#  <tr><td align="right" width="130">09:00AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/fastly-rallies-security-luminaries-inspirational-140000385.html" target="_blank">Fastly Rallies Security Luminaries in an Inspirational Short-Form Speaker Series</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Business Wire</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Jan-31-22 10:00AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/heres-why-fastly-fsly-great-150003512.html" target="_blank">Here's Why Fastly (FSLY) Is a Great 'Buy the Bottom' Stock Now</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Zacks</span> <span class="body-table-news-gain">+14.41%</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Jan-28-22 05:38PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/long-walk-management-lp-buys-223829981.html" target="_blank">Long Walk Management Lp Buys Snowflake Inc, AppFolio Inc, RH, Sells Cloudflare Inc, Fastly Inc, ...</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> GuruFocus.com</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Jan-27-22 09:00AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/fastly-demand-learning-center-unlocks-140000422.html" target="_blank">Fastlys New On-Demand Learning Center Unlocks Self-Paced Technical Training At Scale</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Business Wire</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Jan-26-22 05:35PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/xilinx-xlnx-beats-q3-earnings-223510603.html" target="_blank">Xilinx (XLNX) Beats Q3 Earnings and Revenue Estimates</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Zacks</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Jan-25-22 11:53AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/01/25/why-fastly-stock-is-falling-today/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">Why Fastly Stock Is Falling Today</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span> <span class="body-table-news-loss">-5.25%</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Jan-24-22 04:05PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/fastly-announces-complete-dismissal-shareholder-210500581.html" target="_blank">Fastly Announces Complete Dismissal of Shareholder Class Action and Derivative Lawsuits</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Business Wire</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Jan-23-22 05:36AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/01/23/4-stocks-can-turn-100000-into-1-million-by-2030/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">4 Stocks That Can Turn $100,000 Into $1 Million by 2030</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Jan-21-22 09:38PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/liberty-one-investment-management-llc-023816725.html" target="_blank">Liberty One Investment Management, Llc Buys Fastly Inc, Kratos Defense &amp; Security Solutions ...</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> GuruFocus.com</span> <span class="body-table-news-loss">-5.45%</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Jan-19-22 04:05PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/fastly-announce-fourth-quarter-full-210500696.html" target="_blank">Fastly to Announce Fourth Quarter and Full Year 2021 Financial Results</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Business Wire</span></div></div></td></tr>
#  <tr><td align="right" width="130">09:38AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/adirondack-retirement-specialists-inc-buys-143808501.html" target="_blank">Adirondack Retirement Specialists, Inc. Buys IDT Corp, Camping World Holdings Inc, Semler ...</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> GuruFocus.com</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Jan-18-22 08:12AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/01/18/why-investors-should-be-bearish-on-fastly-for-2022/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">Why Investors Should Be Bearish on Fastly for 2022</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Jan-17-22 06:15AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/01/17/2-top-bargain-stocks-ready-for-a-bull-run/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">2 Top Bargain Stocks Ready for a Bull Run</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Jan-14-22 06:15PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/fastly-fsly-stock-sinks-market-231511266.html" target="_blank">Fastly (FSLY) Stock Sinks As Market Gains: What You Should Know</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Zacks</span></div></div></td></tr>
#  <tr><td align="right" width="130">02:26PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/01/14/why-fastly-pinterest-and-block-stocks-all-slipped/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">Why Fastly, Pinterest, and Block Stocks All Slipped on Friday</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Jan-10-22 07:50AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://realmoney.thestreet.com/investing/fastly-is-still-searching-for-a-bottom-on-the-charts-15880080?puc=yahoo&amp;cm_ven=YAHOO" target="_blank">Fastly Is Still Searching for a Bottom on the Charts</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> TheStreet.com</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Jan-08-22 07:45AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/loss-making-fastly-nyse-fsly-124504904.html" target="_blank">Loss-making Fastly (NYSE:FSLY) sheds a further US$287m, taking total shareholder losses to 63% over 1 year</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Simply Wall St.</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Jan-06-22 06:15PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/fastly-fsly-dips-more-broader-231511600.html" target="_blank">Fastly (FSLY) Dips More Than Broader Markets: What You Should Know</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Zacks</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Jan-03-22 08:43AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/morgan-stanley-set-fastly-target-134343118.html" target="_blank">Morgan Stanley Set Fastlys Target Price at $43, Says 2022 a Year of Transition</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> FX Empire</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Dec-30-21 04:36PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2021/12/30/why-fastly-pinterest-and-skillz-stocks-were-all-up/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">Why Fastly, Pinterest, and Skillz Stocks Were All Up Big Today</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span> <span class="body-table-news-gain">+6.10%</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Dec-29-21 05:06AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2021/12/29/4-high-growth-trends-youll-want-to-invest-in-2022/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">4 High-Growth Trends You'll Want to Invest in for 2022</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Dec-28-21 04:31PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2021/12/28/why-fastly-teladoc-and-block-shares-all-fell-on-tu/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">Why Fastly, Teladoc, and Block Shares All Fell on Tuesday</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Dec-24-21 01:38AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/morgan-stanley-institutional-fund-inc-063802558.html" target="_blank">Morgan Stanley Institutional Fund Inc Buys GoodRx Holdings Inc, Affirm Holdings Inc, Cricut ...</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> GuruFocus.com</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Dec-23-21 11:30AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/3-sleeper-stocks-buy-now-163053758.html" target="_blank">3 Sleeper Stocks to Buy Now Before 2022 Rolls In</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> InvestorPlace</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Dec-21-21 05:05AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2021/12/21/5-beaten-down-growth-stocks-that-can-soar-in-2022/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">5 Beaten-Down Growth Stocks That Can Soar in 2022</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span> <span class="body-table-news-gain">+6.31%</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Dec-16-21 06:00AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/despite-recent-decline-net-stock-110018558.html" target="_blank">Despite a Recent Decline, NET Stock Is Still Frothy</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> InvestorPlace</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Dec-15-21 10:49AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/cloudflare-stock-could-rough-2022-154956189.html" target="_blank">Cloudflare Stock Could Have a Rough 2022</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> InvestorPlace</span></div></div></td></tr>
#  <tr><td align="right" width="130">09:00AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/fastly-powers-uptime-reliability-real-140000521.html" target="_blank">Fastly Powers Uptime and Reliability With Real-Time Insights Into Origin-to-Edge Traffic Data</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Business Wire</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Dec-14-21 09:38PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/vaneck-social-sentiment-etf-buys-023810546.html" target="_blank">VanEck Social Sentiment ETF Buys BlackBerry, AMC Entertainment Holdings Inc, Pfizer Inc, Sells ...</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> GuruFocus.com</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Dec-13-21 01:24PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2021/12/13/why-pinterest-fastly-and-teladoc-health-stocks-sli/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">Why Pinterest, Fastly, and Teladoc Health Stocks Slipped on Monday</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
#  <tr><td align="right" width="130">09:00AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/fastly-names-margaret-arakawa-chief-140000863.html" target="_blank">Fastly Names Margaret Arakawa as Chief Marketing Officer</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Business Wire</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Dec-12-21 10:00AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.wsj.com/articles/companies-upend-plans-on-covid-19-vaccines-and-office-returns-again-11639321203?siteid=yhoof2" target="_blank">Companies Upend Plans on Covid-19 Vaccines and Office Returns, Again</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> The Wall Street Journal</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Dec-09-21 12:19PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2021/12/09/why-fastly-stock-is-falling-today/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">Why Fastly Stock Is Falling Today</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Dec-08-21 01:43PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2021/12/08/why-fastly-stock-jumped-10-today/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">Why Fastly Stock Jumped 10% Today</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span> <span class="body-table-news-gain">+9.53%</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Dec-07-21 02:00PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/7-web3-stocks-buy-betting-190035567.html" target="_blank">7 Web3 Stocks to Buy if Youre Betting on a Blockchain-Based Internet</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> InvestorPlace</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Dec-06-21 05:11PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2021/12/06/why-fastly-stock-crashed-in-november/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">Why Fastly Stock Crashed 19.5% in November</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
# ...
#  <tr><td align="right" style="white-space:nowrap" width="130">Mar-17-22 08:01PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/top-investment-tips-for-a-stocks-and-shares-isa-000144072.html" target="_blank">Top investment tips for a stocks and shares ISA</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Yahoo Finance UK</span></div></div></td></tr>
#  <tr><td align="right" width="130">07:51PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/10-reddit-stocks-buy-march-235142231.html" target="_blank">10 Reddit Stocks to Buy in March</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> InvestorPlace</span></div></div></td></tr>
#  <tr><td align="right" width="130">04:12PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/why-buy-cybersecurity-stocks-etfs-201208771.html" target="_blank">Why You Should Buy Cybersecurity Stocks &amp; ETFs Now</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Zacks</span></div></div></td></tr>
#  <tr><td align="right" width="130">04:06PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/video/russia-ukraine-war-keeps-away-200609309.html" target="_blank">Russia-Ukraine war keeps me away from going all-in on tech stocks, portfolio manager says</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Yahoo Finance Video</span></div></div></td></tr>
#  <tr><td align="right" width="130">03:24PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/video/stocks-turn-higher-oil-biggest-192418632.html" target="_blank">Stocks turn higher, oil has biggest day since November 2020</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Yahoo Finance Video</span></div></div></td></tr>
#  <tr><td align="right" width="130">01:13PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/buy-oversold-tech-stocks-especially-apple-analyst-171303333.html" target="_blank">Buy oversold tech stocks, especially Apple: Analyst</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Yahoo Finance</span></div></div></td></tr>
#  <tr><td align="right" width="130">12:00PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/ransomware-hackers-used-ai-images-160000424.html" target="_blank">Ransomware Hackers Used AI Images, Microsoft Flaw in Campaign</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Bloomberg</span></div></div></td></tr>
#  <tr><td align="right" width="130">11:38AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/microsoft-data-centres-heat-finnish-153824623.html" target="_blank">Microsoft data centres to heat Finnish homes, cutting emissions</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Reuters</span></div></div></td></tr>
#  <tr><td align="right" width="130">10:46AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/video/market-strategist-talks-stocks-investing-144648659.html" target="_blank">Market strategist talks stocks, investing amid rising rates, and the metaverse ETF</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Yahoo Finance Video</span></div></div></td></tr>
#  <tr><td align="right" width="130">09:00AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/apple-google-brawling-peers-over-130008881.html" target="_blank">Apple and Google Are Brawling With Peers Over Future of the App Store</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Bloomberg</span></div></div></td></tr>
#  <tr><td align="right" width="130">08:12AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/03/17/3-growth-stocks-that-could-be-headed-for-trouble/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">3 Growth Stocks That Could Be Headed for Trouble</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
#  <tr><td align="right" width="130">07:15AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/microsoft-faces-eu-antitrust-complaint-111534029.html" target="_blank">Microsoft faces EU antitrust complaint about its cloud computing business</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Reuters</span></div></div></td></tr>
#  <tr><td align="right" width="130">07:10AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/03/17/why-microsoft-has-edge-over-facebook-in-metaverse/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">Why Microsoft Has an Edge Over Facebook in the Metaverse</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
#  <tr><td align="right" width="130">06:20AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/invesco-p-500-top-50-102010079.html" target="_blank">Should Invesco S&amp;P 500 Top 50 ETF (XLG) Be on Your Investing Radar?</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Zacks</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Mar-16-22 06:30PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/value-investors-shouldnt-scared-off-223048973.html" target="_blank">Value Investors Shouldn't Be Scared Off by War</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> GuruFocus.com</span></div></div></td></tr>
#  <tr><td align="right" width="130">04:05PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/box-forecasts-annual-sales-growth-200500890.html" target="_blank">Box Forecasts Annual Sales Growth of Up to 17% in 2025</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Bloomberg</span></div></div></td></tr>
#  <tr><td align="right" width="130">01:51PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/microsoft-accidentally-promotes-fake-amazon-175113400.html" target="_blank">Microsoft accidentally promotes fake Amazon website pushing an Elon Musk bitcoin scam</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> The Independent</span></div></div></td></tr>
#  <tr><td align="right" width="130">01:10PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/rogers-microsoft-announce-strategic-alliance-171000111.html" target="_blank">Rogers and Microsoft announce strategic alliance to revolutionize hybrid workplace communications and power 5G innovation across Canada with Azure</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> CNW Group</span></div></div></td></tr>
#  <tr><td align="right" width="130">12:31PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/rogers-microsoft-announce-strategic-alliance-163100641.html" target="_blank">Rogers and Microsoft announce strategic alliance to revolutionize hybrid workplace communications and power 5G innovation across Canada with Azure</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> GlobeNewswire</span></div></div></td></tr>
#  <tr><td align="right" width="130">12:01PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/mongodb-mdb-expands-multi-partnership-160104344.html" target="_blank">MongoDB (MDB) Expands Multi-Year Partnership With AWS</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Zacks</span></div></div></td></tr>
#  <tr><td align="right" width="130">09:46AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/video/russia-ukraine-war-financial-sector-134639928.html" target="_blank">Russia-Ukraine war: Financial sector 'on high alert' for cyberattacks, Crowdstrike CEO says</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Yahoo Finance Video</span></div></div></td></tr>
#  <tr><td align="right" width="130">09:21AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/10-penny-stocks-upcoming-growth-132126710.html" target="_blank">10 Penny Stocks with Upcoming Growth Catalysts</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Insider Monkey</span></div></div></td></tr>
#  <tr><td align="right" width="130">09:21AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/rajiv-jain-gqg-partners-portfolio-132108183.html" target="_blank">Rajiv Jains GQG Partners Portfolio: 10 Dividend Stock Picks</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Insider Monkey</span></div></div></td></tr>
#  </table>,
#  'METV': <table border="0" cellpadding="1" cellspacing="0" class="fullview-news-outer" id="news-table" width="100%">
#  <tr><td align="right" style="white-space:nowrap" width="130">Mar-23-22 02:52PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/metaverse-presents-half-a-trillion-dollar-opportunity-pro-shares-strategist-185227405.html" target="_blank">Metaverse presents half a trillion-dollar opportunity: ProShares strategist</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Yahoo Finance</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Mar-22-22 12:00AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/roundhill-ball-metaverse-ucits-etf-040000982.html" target="_blank">Roundhill Ball Metaverse UCITS ETF (METV) Launches in Germany</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> PR Newswire</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Mar-17-22 04:00AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/proshares-launches-metaverse-etf-080000360.html" target="_blank">ProShares Launches Metaverse ETF</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> ETF.com</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Mar-11-22 03:30AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/roundhill-investments-launch-metaverse-etf-083000121.html" target="_blank">Roundhill Investments to Launch Metaverse ETF in Germany</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> PR Newswire</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Feb-07-22 09:00AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/roundhill-ball-metaverse-etf-reduces-140000048.html" target="_blank">Roundhill Ball Metaverse ETF Reduces Management Fee</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> PR Newswire</span></div></div></td></tr>
#  <tr><td align="right" width="130">08:15AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/etf-odds-ends-2022-leads-131500708.html" target="_blank">ETF Odds &amp; Ends: 2022 Leads 2021 For Launches</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> ETF.com</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Feb-03-22 03:30PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/newly-launched-punk-times-meta-203000174.html" target="_blank">Newly Launched 'PUNK' Times Metas Meltdown</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> ETF.com</span> <span class="body-table-news-loss">-6.94%</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Feb-02-22 06:30PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/meta-miss-reverberates-etfs-233000972.html" target="_blank">Metas Miss Reverberates Through ETFs</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> ETF.com</span></div></div></td></tr>
#  <tr><td align="right" width="130">12:39PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/video/stocks-focus-alphabet-netflix-meta-173928937.html" target="_blank">Stocks in focus: Alphabet, Netflix, Meta, Amazon, Tesla</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Yahoo Finance Video</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Jan-28-22 12:30PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/timing-everything-etfs-173000643.html" target="_blank">Timing Is Everything For ETFs</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> ETF.com</span></div></div></td></tr>
#  <tr><td align="right" style="white-space:nowrap" width="130">Jan-14-22 05:30PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/roundhill-gives-meta-ticker-223000816.html" target="_blank">Roundhill Gives Up META Ticker</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> ETF.com</span></div></div></td></tr>
#  </table>}

# %%
parsed_news = []

# Iterate through the news
for file_name, news_table in news_tables.items():
    # Iterate through all tr tags in 'news_table'
    for x in news_table.findAll('tr'):
        # read the text from each tr tag into text
        # get text from a only
        text = x.a.get_text() 
        # splite text in the td tag into a list 
        date_scrape = x.td.text.split()
        # if the length of 'date_scrape' is 1, load 'time' as the only element

        if len(date_scrape) == 1:
            time = date_scrape[0]
            
        # else load 'date' as the 1st element and 'time' as the second    
        else:
            date = date_scrape[0]
            time = date_scrape[1]
        # Extract the ticker from the file name, get the string up to the 1st '_'  
        ticker = file_name.split('_')[0]
        
        # Append ticker, date, time and headline as a list to the 'parsed_news' list
        parsed_news.append([ticker, date, time, text])
        
parsed_news
# Out:
# [['FSLY',
#   'Mar-23-22',
#   '06:15PM',
#   'Fastly (FSLY) Stock Moves -0.98%: What You Should Know'],
#  ['FSLY',
#   'Mar-23-22',
#   '02:23PM',
#   'Fastly Only Vendor Named Gartner Peer Insights Customers Choice for Web Application and API Protection for Four Consecutive Years'],
#  ['FSLY',
#   'Mar-22-22',
#   '08:01AM',
#   'Cloudflare Doesnt Offer Investors Security at This Price'],
#  ['FSLY',
#   'Mar-21-22',
#   '10:58AM',
#   "Will Adobe's (ADBE) Q1 Earnings Gain From Digital Media?"],
#  ['FSLY',
#   'Mar-21-22',
#   '05:06AM',
#   "10 Stocks I've Bought During the Market Sell-Off"],
#  ['FSLY',
#   'Mar-20-22',
#   '05:06AM',
#   '3 Tech Stocks That Can Turn $200,000 Into $1 Million in 8 Years (or Less)'],
#  ['FSLY',
#   'Mar-17-22',
#   '09:00AM',
#   'Fastly Named a Leader in IDC MarketScape for Worldwide Commercial CDN 2022 Vendor Assessment'],
#  ['FSLY',
#   'Mar-14-22',
#   '05:06AM',
#   '2 Metaverse Stocks to Buy Hand Over Fist and 1 to Avoid Like the Plague'],
#  ['FSLY',
#   'Mar-12-22',
#   '07:00AM',
#   'Zendesk Could 10X Customer Return -- or Fall the Way of Fastly, New Relic'],
#  ['FSLY',
#   'Mar-03-22',
#   '03:21PM',
#   'Why Shares of Pinterest, Fastly, and Block Slipped on Thursday'],
#  ['FSLY', 'Mar-02-22', '03:07PM', 'Why Fastly Stock Tanked 35.1% in February'],
#  ['FSLY',
#   'Mar-02-22',
#   '09:00AM',
#   'Fastly Accelerates Edge Adoption with New [email\xa0protected] Partner Ecosystem'],
#  ['FSLY',
#   'Feb-28-22',
#   '05:00PM',
#   'Fastly to Present at the Morgan Stanley Technology, Media, and Telecom Conference'],
#  ['FSLY',
#   'Feb-24-22',
#   '11:07AM',
#   'Why Nvidia, Apple, and Fastly Stocks Are All Falling Today'],
#  ['FSLY',
#   'Feb-23-22',
#   '01:04PM',
#   'Why Lemonade, Fastly, and Block Are Falling Today'],
#  ['FSLY',
#   'Feb-23-22',
#   '11:00AM',
#   'Raymond James: 2 Strong Buy Stocks That Could Climb Over 50%'],
#  ['FSLY',
#   'Feb-23-22',
#   '10:00AM',
#   "Here's Why Fastly (FSLY) is Poised for a Turnaround After Losing 28.6% in 4 Weeks"],
#  ['FSLY',
#   'Feb-20-22',
#   '03:22AM',
#   'Billionaire Ken Griffin Is Loading Up on These 10 Stocks'],
#  ['FSLY',
#   'Feb-18-22',
#   '05:55PM',
#   'Why Fastly Stock Fell Again Today Despite an Analyst Upgrade'],
#  ['FSLY',
#   'Feb-18-22',
#   '11:19AM',
#   "Raymond James Turns Bullish On Fastly, Cites Recent Pullback As 'Overreaction'"],
#  ['FSLY', 'Feb-18-22', '08:40AM', "4 Red Flags for Fastly's Future"],
#  ['FSLY',
#   'Feb-18-22',
#   '02:51AM',
#   'Roku, DraftKings Shake Shack Fall Premarket; Livent, Fastly Rise'],
#  ['FSLY',
#   'Feb-17-22',
#   '01:01PM',
#   '3 Stocks to Buy While Markets Deal With an Enemy Fed'],
#  ['FSLY',
#   'Feb-17-22',
#   '11:58AM',
#   'Fastly Stock Is Tumbling. The Companys Guidance May Be Too Conservative.'],
#  ['FSLY',
#   'Feb-17-22',
#   '10:50AM',
#   "Here's Why Fastly Is Plunging by Another 30% Today"],
#  ['FSLY',
#   'Feb-17-22',
#   '10:18AM',
#   'Palantir stock and Fastly stock plunge on missed earnings expectations'],
#  ['FSLY',
#   'Feb-17-22',
#   '10:13AM',
#   'Fastly (FSLY) Reports Q4 Loss, Tops Revenue Estimates'],
#  ['FSLY',
#   'Feb-17-22',
#   '09:28AM',
#   'Fastly Stock Drops 30% After Earnings. Whats Spooking Investors.'],
#  ['FSLY',
#   'Feb-17-22',
#   '08:33AM',
#   'Why These 2 Cloud Stocks Are Getting Pummeled Thursday'],
#  ['FSLY',
#   'Feb-17-22',
#   '07:04AM',
#   'Fastly Tumbles as 2022 Loss Seen Wider, Brokerages Cut Targets'],
#  ['FSLY',
#   'Feb-17-22',
#   '06:34AM',
#   'Fastly Earnings Beat Estimates. Why the Stock Is Tumbling.'],
#  ['FSLY',
#   'Feb-17-22',
#   '03:00AM',
#   'Walmart, DoorDash, Cisco Rise Premarket; Fastly, TripAdvisor Slump'],
#  ['FSLY',
#   'Feb-16-22',
#   '06:47PM',
#   'Fastly Shares Swoon as Guidance Misses Estimates'],
#  ['FSLY',
#   'Feb-16-22',
#   '06:15PM',
#   'Fastly (FSLY) Reports Q4 Loss, Tops Revenue Estimates'],
#  ['FSLY',
#   'Feb-16-22',
#   '05:46PM',
#   "Fastly Stock Is Sliding After the Company's Earnings"],
#  ['FSLY',
#   'Feb-16-22',
#   '04:43PM',
#   'Fastly stock plunges after forecast calls for bigger 2022 growth slowdown than expected'],
#  ['FSLY',
#   'Feb-16-22',
#   '04:05PM',
#   'Fastly Announces Fourth Quarter and Full Year 2021 Financial Results'],
#  ['FSLY',
#   'Feb-15-22',
#   '08:38AM',
#   'Fastly vs. Twilio: Which Is the Best Buy Now?'],
#  ['FSLY',
#   'Feb-15-22',
#   '06:05AM',
#   '2 Growth Stocks Reporting Earnings This Week'],
#  ['FSLY',
#   'Feb-14-22',
#   '12:27PM',
#   "Shopify (SHOP) to Report Q4 Earnings: What's in the Cards?"],
#  ['FSLY',
#   'Feb-14-22',
#   '11:50AM',
#   'Cisco Systems (CSCO) to Report Q2 Earnings: Factors to Note'],
#  ['FSLY',
#   'Feb-11-22',
#   '05:26PM',
#   "Here's Another Reason Why Shopify Is an Unstoppable E-Commerce Stock to Buy in 2022"],
#  ['FSLY',
#   'Feb-11-22',
#   '01:56PM',
#   'Why Fastly (FSLY) Might Surprise This Earnings Season'],
#  ['FSLY',
#   'Feb-11-22',
#   '01:10PM',
#   'IPG Photonics (IPGP) to Post Q4 Earnings: What to Expect?'],
#  ['FSLY',
#   'Feb-11-22',
#   '12:14PM',
#   "Fastly (FSLY) to Report Q4 Earnings: What's in the Cards?"],
#  ['FSLY',
#   'Feb-09-22',
#   '03:01PM',
#   'Fastly (FSLY) Expected to Beat Earnings Estimates: Can the Stock Move Higher?'],
#  ['FSLY',
#   'Feb-08-22',
#   '04:39PM',
#   'Are These Bargain Stocks Worth a Second Look Right Now?'],
#  ['FSLY',
#   'Feb-08-22',
#   '11:35AM',
#   'These 15 stocks rose 100% or more during the pandemic, but theyve since been crushed. Is it now time to buy?'],
#  ['FSLY',
#   'Feb-08-22',
#   '09:00AM',
#   "Fastly Launches Edge Deployment Option for Industry's First and Only Unified WAF"],
#  ['FSLY',
#   'Feb-07-22',
#   '06:15PM',
#   'Fastly (FSLY) Gains As Market Dips: What You Should Know'],
#  ['FSLY',
#   'Feb-03-22',
#   '01:38PM',
#   'Longitude (Cayman) Ltd. Buys Tesla Inc, Meta Platforms Inc, PayPal Holdings Inc, Sells Invitae ...'],
#  ['FSLY',
#   'Feb-03-22',
#   '11:33AM',
#   "onsemi (ON) to Report Q4 Earnings: What's in the Cards?"],
#  ['FSLY',
#   'Feb-02-22',
#   '01:38PM',
#   'Derbend Asset Management Buys Global X U.S. ...'],
#  ['FSLY',
#   'Feb-02-22',
#   '12:22PM',
#   'Why Pinterest, Fastly, and Teladoc Stocks Fell Sharply on Wednesday'],
#  ['FSLY',
#   'Feb-01-22',
#   '06:15PM',
#   'Fastly (FSLY) Outpaces Stock Market Gains: What You Should Know'],
#  ['FSLY',
#   'Feb-01-22',
#   '11:43AM',
#   "Skyworks (SWKS) to Report Q1 Earnings: What's in the Cards?"],
#  ['FSLY',
#   'Feb-01-22',
#   '10:03AM',
#   "Microchip (MCHP) to Report Q3 Earnings: What's in the Cards?"],
#  ['FSLY',
#   'Feb-01-22',
#   '09:00AM',
#   'Fastly Rallies Security Luminaries in an Inspirational Short-Form Speaker Series'],
#  ['FSLY',
#   'Jan-31-22',
#   '10:00AM',
#   "Here's Why Fastly (FSLY) Is a Great 'Buy the Bottom' Stock Now"],
#  ['FSLY',
#   'Jan-28-22',
#   '05:38PM',
#   'Long Walk Management Lp Buys Snowflake Inc, AppFolio Inc, RH, Sells Cloudflare Inc, Fastly Inc, ...'],
#  ['FSLY',
#   'Jan-27-22',
#   '09:00AM',
#   'Fastlys New On-Demand Learning Center Unlocks Self-Paced Technical Training At Scale'],
#  ['FSLY',
#   'Jan-26-22',
#   '05:35PM',
#   'Xilinx (XLNX) Beats Q3 Earnings and Revenue Estimates'],
#  ['FSLY', 'Jan-25-22', '11:53AM', 'Why Fastly Stock Is Falling Today'],
#  ['FSLY',
#   'Jan-24-22',
#   '04:05PM',
#   'Fastly Announces Complete Dismissal of Shareholder Class Action and Derivative Lawsuits'],
#  ['FSLY',
#   'Jan-23-22',
#   '05:36AM',
#   '4 Stocks That Can Turn $100,000 Into $1 Million by 2030'],
#  ['FSLY',
#   'Jan-21-22',
#   '09:38PM',
#   'Liberty One Investment Management, Llc Buys Fastly Inc, Kratos Defense & Security Solutions ...'],
#  ['FSLY',
#   'Jan-19-22',
#   '04:05PM',
#   'Fastly to Announce Fourth Quarter and Full Year 2021 Financial Results'],
#  ['FSLY',
#   'Jan-19-22',
#   '09:38AM',
#   'Adirondack Retirement Specialists, Inc. Buys IDT Corp, Camping World Holdings Inc, Semler ...'],
#  ['FSLY',
#   'Jan-18-22',
#   '08:12AM',
#   'Why Investors Should Be Bearish on Fastly for 2022'],
#  ['FSLY', 'Jan-17-22', '06:15AM', '2 Top Bargain Stocks Ready for a Bull Run'],
#  ['FSLY',
#   'Jan-14-22',
#   '06:15PM',
#   'Fastly (FSLY) Stock Sinks As Market Gains: What You Should Know'],
#  ['FSLY',
#   'Jan-14-22',
#   '02:26PM',
#   'Why Fastly, Pinterest, and Block Stocks All Slipped on Friday'],
#  ['FSLY',
#   'Jan-10-22',
#   '07:50AM',
#   'Fastly Is Still Searching for a Bottom on the Charts'],
#  ['FSLY',
#   'Jan-08-22',
#   '07:45AM',
#   'Loss-making Fastly (NYSE:FSLY) sheds a further US$287m, taking total shareholder losses to 63% over 1 year'],
#  ['FSLY',
#   'Jan-06-22',
#   '06:15PM',
#   'Fastly (FSLY) Dips More Than Broader Markets: What You Should Know'],
#  ['FSLY',
#   'Jan-03-22',
#   '08:43AM',
#   'Morgan Stanley Set Fastlys Target Price at $43, Says 2022 a Year of Transition'],
#  ['FSLY',
#   'Dec-30-21',
#   '04:36PM',
#   'Why Fastly, Pinterest, and Skillz Stocks Were All Up Big Today'],
#  ['FSLY',
#   'Dec-29-21',
#   '05:06AM',
#   "4 High-Growth Trends You'll Want to Invest in for 2022"],
#  ['FSLY',
#   'Dec-28-21',
#   '04:31PM',
#   'Why Fastly, Teladoc, and Block Shares All Fell on Tuesday'],
#  ['FSLY',
#   'Dec-24-21',
#   '01:38AM',
#   'Morgan Stanley Institutional Fund Inc Buys GoodRx Holdings Inc, Affirm Holdings Inc, Cricut ...'],
#  ['FSLY',
#   'Dec-23-21',
#   '11:30AM',
#   '3 Sleeper Stocks to Buy Now Before 2022 Rolls In'],
#  ['FSLY',
#   'Dec-21-21',
#   '05:05AM',
#   '5 Beaten-Down Growth Stocks That Can Soar in 2022'],
#  ['FSLY',
#   'Dec-16-21',
#   '06:00AM',
#   'Despite a Recent Decline, NET Stock Is Still Frothy'],
#  ['FSLY', 'Dec-15-21', '10:49AM', 'Cloudflare Stock Could Have a Rough 2022'],
#  ['FSLY',
#   'Dec-15-21',
#   '09:00AM',
#   'Fastly Powers Uptime and Reliability With Real-Time Insights Into Origin-to-Edge Traffic Data'],
#  ['FSLY',
#   'Dec-14-21',
#   '09:38PM',
#   'VanEck Social Sentiment ETF Buys BlackBerry, AMC Entertainment Holdings Inc, Pfizer Inc, Sells ...'],
#  ['FSLY',
#   'Dec-13-21',
#   '01:24PM',
#   'Why Pinterest, Fastly, and Teladoc Health Stocks Slipped on Monday'],
#  ['FSLY',
#   'Dec-13-21',
#   '09:00AM',
#   'Fastly Names Margaret Arakawa as Chief Marketing Officer'],
#  ['FSLY',
#   'Dec-12-21',
#   '10:00AM',
#   'Companies Upend Plans on Covid-19 Vaccines and Office Returns, Again'],
#  ['FSLY', 'Dec-09-21', '12:19PM', 'Why Fastly Stock Is Falling Today'],
#  ['FSLY', 'Dec-08-21', '01:43PM', 'Why Fastly Stock Jumped 10% Today'],
#  ['FSLY',
#   'Dec-07-21',
#   '02:00PM',
#   '7 Web3 Stocks to Buy if Youre Betting on a Blockchain-Based Internet'],
#  ['FSLY',
#   'Dec-06-21',
#   '05:11PM',
#   'Why Fastly Stock Crashed 19.5% in November'],
#  ['FSLY',
#   'Dec-03-21',
#   '02:56PM',
#   'Why Fastly Stock Popped, Then Dropped on Friday'],
#  ['FSLY',
#   'Dec-01-21',
#   '04:05PM',
#   'Fastly to Present at the Raymond James Technology Investors Conference'],
#  ['FSLY', 'Nov-29-21', '05:05PM', 'Why Fastly Stock Rose Higher on Monday'],
#  ['FSLY',
#   'Nov-29-21',
#   '09:00AM',
#   'Fastly Names Lakshmi Sharma as New Chief Product Officer'],
#  ['FSLY',
#   'Nov-19-21',
#   '09:47AM',
#   '10 New Stock Picks of Billionaire Stanley Druckenmiller'],
#  ['FSLY',
#   'Nov-18-21',
#   '07:09AM',
#   'When Should You Buy Fastly, Inc. (NYSE:FSLY)?'],
#  ['FSLY',
#   'Nov-17-21',
#   '08:40AM',
#   'Fastly Q3 Earnings: What Investors Should Know'],
#  ['IMMR',
#   'Mar-09-22',
#   '05:47AM',
#   'A Immersion Corporation (NASDAQ:IMMR) insider increased their holdings by 628% last year'],
#  ['IMMR',
#   'Feb-24-22',
#   '04:15PM',
#   'Immersion Corporation Reports Fourth Quarter 2021 Results'],
#  ['IMMR',
#   'Feb-23-22',
#   '09:05AM',
#   'Immersion and Nissha Partner on New Automotive Interface Designs'],
#  ['IMMR',
#   'Feb-22-22',
#   '08:55AM',
#   'Immersion Signs License Agreement with Duck-il for Automotive Interfaces'],
#  ['IMMR',
#   'Feb-16-22',
#   '05:14AM',
#   'Zacks Industry Outlook Highlights: Logitech, Mercury Systems, Stratasys and Immersion'],
#  ['IMMR',
#   'Feb-11-22',
#   '07:29AM',
#   "Here's What Immersion Corporation's (NASDAQ:IMMR) Shareholder Ownership Structure Looks Like"],
#  ['IMMR',
#   'Feb-02-22',
#   '01:38PM',
#   'Investment Management Of Virginia Llc Buys PowerShares QQQ Trust Ser 1, Dow Inc, Apple Inc, ...'],
#  ['IMMR',
#   'Jan-17-22',
#   '05:41AM',
#   'Top 10 Stock Picks of Ali Motameds Invenomic Capital Management'],
#  ['IMMR',
#   'Jan-06-22',
#   '07:36AM',
#   "Will Weakness in Immersion Corporation's (NASDAQ:IMMR) Stock Prove Temporary Given Strong Fundamentals?"],
#  ['IMMR',
#   'Dec-01-21',
#   '06:07AM',
#   'Immersion (NASDAQ:IMMR) investors are sitting on a loss of 43% if they invested five years ago'],
#  ['IMMR',
#   'Nov-30-21',
#   '10:34AM',
#   '3 Metaverse Moonshots With Actual 10x Potential'],
#  ['IMMR',
#   'Nov-28-21',
#   '05:55AM',
#   '2 Under-the-Radar Metaverse Stocks That Could Make You a Fortune'],
#  ['IMMR',
#   'Nov-16-21',
#   '12:46PM',
#   'Immersion Insider Trades $2.4M In Company Stock'],
#  ['IMMR',
#   'Nov-11-21',
#   '11:23AM',
#   'Immersion Insider Trades $13M In Company Stock'],
#  ['IMMR',
#   'Nov-03-21',
#   '04:15PM',
#   'Immersion Corporation Reports Third Quarter 2021 Results'],
#  ['IMMR',
#   'Oct-26-21',
#   '12:15PM',
#   'Do Hedge Funds Love Immersion Corporation (IMMR)?'],
#  ['IMMR',
#   'Oct-26-21',
#   '09:37AM',
#   'Immersion (NASDAQ:IMMR) Is Looking To Continue Growing Its Returns On Capital'],
#  ['IMMR',
#   'Sep-29-21',
#   '03:28PM',
#   'The Funded: 20 Bay Area startups just raised a combined $700M'],
#  ['IMMR', 'Aug-17-21', '12:43PM', 'Why Immersion Stock Plunged on Tuesday'],
#  ['IMMR',
#   'Aug-16-21',
#   '08:00PM',
#   'Immersion Corporation (IMMR) Q2 2021 Earnings Call Transcript'],
#  ['IMMR',
#   'Aug-16-21',
#   '04:15PM',
#   'Immersion Corporation Reports Second Quarter 2021 Results'],
#  ['IMMR',
#   'Aug-12-21',
#   '04:05PM',
#   'Immersion Signs Agreement to Make Haptic Technology License Available To Mobile OEMs Through TITAN Haptics'],
#  ['IMMR',
#   'Aug-12-21',
#   '05:00AM',
#   "An Intrinsic Calculation For Immersion Corporation (NASDAQ:IMMR) Suggests It's 47% Undervalued"],
#  ['IMMR',
#   'Aug-11-21',
#   '08:45AM',
#   'Immersion Expands License Agreement with Stanley for Automotive Products'],
#  ['IMMR',
#   'Jul-27-21',
#   '04:30PM',
#   'Immersion to Report Second Quarter 2021 Results and Host Quarterly Conference Call on August 16, 2021'],
#  ['IMMR',
#   'Jul-21-21',
#   '10:07PM',
#   'Immersion Corporation (IMMR) Fell Out Of Favor With Hedge Funds?'],
#  ['IMMR',
#   'Jul-13-21',
#   '04:17AM',
#   "Is Immersion Corporation's (NASDAQ:IMMR) Shareholder Ownership Skewed Towards Insiders?"],
#  ['IMMR',
#   'Jul-06-21',
#   '04:41PM',
#   'Immersion Announces Preliminary Results for Fiscal Second Quarter 2021'],
#  ['IMMR',
#   'Jun-17-21',
#   '08:30AM',
#   'Immersion Renews ASUSTek to a Multi-Year License for TouchSense Software'],
#  ['IMMR',
#   'Jun-13-21',
#   '04:55AM',
#   "How Much Did Immersion's(NASDAQ:IMMR) Shareholders Earn From Share Price Movements Over The Last Three Years?"],
#  ['IMMR',
#   'Jun-11-21',
#   '11:40AM',
#   'LPL vs. IMMR: Which Stock Is the Better Value Option?'],
#  ['IMMR',
#   'Jun-07-21',
#   '07:23AM',
#   'Zacks Industry Outlook Highlights: Logitech, LG Display, Immersion, Microsoft and Zoom Video'],
#  ['IMMR',
#   'May-26-21',
#   '11:40AM',
#   'LPL vs. IMMR: Which Stock Should Value Investors Buy Now?'],
#  ['IMMR',
#   'May-24-21',
#   '10:45AM',
#   'SHAREHOLDER ALERT: Purcell Julie & Lefkowitz LLP Is Investigating Immersion Corporation for Potential Breaches of Fiduciary Duty By Its Board of Directors'],
#  ['IMMR',
#   'May-20-21',
#   '08:30AM',
#   'Immersion Enables Automotive User Interface Designers to Work with Haptic APIs in Kanzi UI Software'],
#  ['IMMR',
#   'May-19-21',
#   '12:00PM',
#   'Immersion (IMMR) Upgraded to Buy: What Does It Mean for the Stock?'],
#  ['IMMR',
#   'May-14-21',
#   '03:38AM',
#   "Immersion Corporation's (NASDAQ:IMMR) Stock Has Been Sliding But Fundamentals Look Strong: Is The Market Wrong?"],
#  ['IMMR',
#   'May-11-21',
#   '08:30AM',
#   'Immersion Renews Panasonic to Multi-Year License for TouchSense Software'],
#  ['IMMR',
#   'May-10-21',
#   '11:40AM',
#   'LPL vs. IMMR: Which Stock Should Value Investors Buy Now?'],
#  ['IMMR',
#   'May-07-21',
#   '03:30PM',
#   'Immersion Corp (IMMR) Q1 2021 Earnings Call Transcript'],
#  ['IMMR',
#   'May-06-21',
#   '04:15PM',
#   'Immersion Corporation Reports First Quarter 2021 Results'],
#  ['IMMR',
#   'Apr-23-21',
#   '11:40AM',
#   'LPL or IMMR: Which Is the Better Value Stock Right Now?'],
#  ['IMMR',
#   'Apr-16-21',
#   '08:30AM',
#   'Immersion to Report First Quarter 2021 Results and Host Quarterly Conference Call on May 6, 2021'],
#  ['IMMR',
#   'Apr-14-21',
#   '03:14AM',
#   'Immersion (NASDAQ:IMMR) Will Be Looking To Turn Around Its Returns'],
#  ['IMMR',
#   'Mar-25-21',
#   '08:52AM',
#   'Is Immersion Corp (IMMR) a Great Growth Stock?'],
#  ['IMMR',
#   'Mar-22-21',
#   '11:40AM',
#   'LPL vs. IMMR: Which Stock Is the Better Value Option?'],
#  ['IMMR',
#   'Mar-11-21',
#   '09:57AM',
#   'The Zacks Analyst Blog Highlights: Cirrus Logic, HighPoint Resources Corp, Immersion Corp, CollPlant Biotechnologies and Suburban Propane Partners'],
#  ['IMMR',
#   'Mar-10-21',
#   '03:56PM',
#   '6 Beaten Down Stocks with Solid Growth Potential'],
#  ['IMMR',
#   'Mar-09-21',
#   '02:37AM',
#   'At US$9.64, Is It Time To Put Immersion Corporation (NASDAQ:IMMR) On Your Watch List?'],
#  ['IMMR',
#   'Mar-05-21',
#   '11:40AM',
#   'LPL or IMMR: Which Is the Better Value Stock Right Now?'],
#  ['IMMR',
#   'Mar-05-21',
#   '09:30AM',
#   'Immersion Corp (IMMR) Q4 2020 Earnings Call Transcript'],
#  ['IMMR',
#   'Mar-04-21',
#   '04:15PM',
#   'Immersion Corporation Reports Fourth Quarter 2020 Results'],
#  ['IMMR', 'Mar-04-21', '03:15PM', 'Immersion Corp. to Host Earnings Call'],
#  ['IMMR', 'Mar-03-21', '10:38AM', "Immersion's Earnings: A Preview"],
#  ['IMMR',
#   'Mar-03-21',
#   '08:45AM',
#   "Immersion (IMMR) to Report Q4 Earnings: What's in Store?"],
#  ['IMMR',
#   'Mar-03-21',
#   '08:30AM',
#   'Immersion and StrikerVR to Collaborate on Advanced Haptic Peripherals for VR and Gaming'],
#  ['IMMR',
#   'Feb-25-21',
#   '08:30AM',
#   'Immersion Announces New Recommended Practice for Broadcasting Haptics'],
#  ['IMMR',
#   'Feb-12-21',
#   '08:30AM',
#   'Immersion Signs Korean-Based Woory Industrial to a New Multi-Year License for Haptic Technology Use in Automotive Touchscreens'],
#  ['IMMR',
#   'Feb-04-21',
#   '08:00AM',
#   'Immersion Announces Preliminary Results for Fiscal Fourth Quarter 2020'],
#  ['IMMR',
#   'Feb-03-21',
#   '08:30AM',
#   'Faurecia and Immersion Partner for Haptic Automotive Technologies'],
#  ['IMMR',
#   'Feb-01-21',
#   '11:40AM',
#   'LPL vs. IMMR: Which Stock Is the Better Value Option?'],
#  ['IMMR',
#   'Feb-01-21',
#   '12:36AM',
#   'Companies Like Immersion (NASDAQ:IMMR) Can Afford To Invest In Growth'],
#  ['IMMR',
#   'Jan-08-21',
#   '07:45AM',
#   'PS5 A Major Catalyst For This Small Cap Video Game Stock; Could Xbox Be Next?'],
#  ['IMMR', 'Jan-05-21', '03:31PM', '6 Video Games Stocks To Watch In 2021'],
#  ['IMMR', 'Dec-29-20', '01:03PM', 'Why Immersion Stock Skyrocketed Today'],
#  ['IMMR',
#   'Dec-29-20',
#   '09:51AM',
#   'Return On Capital Employed Overview: Immersion'],
#  ['IMMR',
#   'Dec-29-20',
#   '08:55AM',
#   'Immersion (IMMR) in Focus: Stock Moves 23.4% Higher'],
#  ['IMMR',
#   'Dec-19-20',
#   '08:03PM',
#   'Is IMMR A Good Stock To Buy Now According To Hedge Funds?'],
#  ['IMMR',
#   'Dec-03-20',
#   '01:24AM',
#   "Would Shareholders Who Purchased Immersion's (NASDAQ:IMMR) Stock Five Years Be Happy With The Share price Today?"],
#  ['IMMR',
#   'Dec-01-20',
#   '09:17AM',
#   "Immersion's (IMMR) Shares March Higher, Can It Continue?"],
#  ['IMMR',
#   'Nov-15-20',
#   '02:18PM',
#   'Immersion: The Thing Behind The Thing For Playstation 5'],
#  ['IMMR',
#   'Nov-07-20',
#   '01:01AM',
#   'Immersion Corp (IMMR) Q3 2020 Earnings Call Transcript'],
#  ['IMMR',
#   'Nov-05-20',
#   '04:15PM',
#   'Immersion Corporation Reports Third Quarter 2020 Results'],
#  ['IMMR', 'Nov-05-20', '03:45PM', 'Immersion Corp. to Host Earnings Call'],
#  ['IMMR',
#   'Oct-19-20',
#   '01:19PM',
#   'Have Insiders Been Buying Immersion Corporation (NASDAQ:IMMR) Shares?'],
#  ['IMMR',
#   'Oct-13-20',
#   '08:30AM',
#   'Immersion Announces Partnership with ANA Avatar XPRIZE to Support Competing Teams in Developing Physical Avatar Systems'],
#  ['IMMR',
#   'Oct-07-20',
#   '04:30PM',
#   'Immersion to Report Third Quarter 2020 Results and Host Quarterly Conference Call on November 5, 2020'],
#  ['IMMR',
#   'Sep-29-20',
#   '08:30AM',
#   'Immersion Signs LG Electronics to a Multi-Year Renewal License for TouchSense® Software'],
#  ['IMMR', 'Sep-23-20', '03:37PM', 'Sidoti-Virtual Investor Conference'],
#  ['IMMR',
#   'Sep-11-20',
#   '02:12PM',
#   'The Zacks Analyst Blog Highlights: LOGI, SSYS and IMMR'],
#  ['IMMR',
#   'Sep-04-20',
#   '11:35AM',
#   "Here's What Immersion Corporation's (NASDAQ:IMMR) Shareholder Ownership Structure Looks Like"],
#  ['IMMR',
#   'Sep-03-20',
#   '12:00PM',
#   "Here's Why Momentum Investors Will Love Immersion (IMMR)"],
#  ['IMMR',
#   'Sep-01-20',
#   '08:04AM',
#   "Immersion's Shares March Higher, Can It Continue?"],
#  ['IMMR',
#   'Aug-06-20',
#   '04:15PM',
#   'Immersion Corporation Reports Second Quarter 2020 Results'],
#  ['IMMR',
#   'Jul-30-20',
#   '04:19PM',
#   "Registration - Sidoti's 2020 Fall Virtual Investor Conference is Now Open"],
#  ['IMMR',
#   'Jul-26-20',
#   '05:08PM',
#   'Why You Should Keep An Eye On This Little-Known Playstation 5 Component Maker'],
#  ['IMMR', 'Jul-24-20', '06:00PM', 'Company Profile for Immersion Corporation'],
#  ['IMMR',
#   'Jul-23-20',
#   '04:15PM',
#   'Immersion to Report Second Quarter 2020 Results and Host Quarterly Conference Call on August 6, 2020'],
#  ['IMMR',
#   'Jul-21-20',
#   '02:21PM',
#   "We're Not Very Worried About Immersion's (NASDAQ:IMMR) Cash Burn Rate"],
#  ['IMMR',
#   'Jul-08-20',
#   '08:30AM',
#   'Immersion Leads Creation of Standards for Haptics'],
#  ['IMMR',
#   'Jul-05-20',
#   '08:45PM',
#   'Should You Avoid Immersion Corporation (IMMR)?'],
#  ['IMMR',
#   'May-27-20',
#   '06:39PM',
#   'Edited Transcript of IMMR earnings conference call or presentation 7-May-20 9:00pm GMT'],
#  ['IMMR',
#   'May-10-20',
#   '10:30AM',
#   'Analysts Have Lowered Expectations For Immersion Corporation (NASDAQ:IMMR) After Its Latest Results'],
#  ['IMMR',
#   'May-08-20',
#   '06:30PM',
#   'Immersion Corp (IMMR) Q1 2020 Earnings Call Transcript'],
#  ['IMMR',
#   'May-07-20',
#   '04:15PM',
#   'Immersion Corporation Reports First Quarter 2020 Results; Company Focus Remains Improving Profitability and Enhancing Shareholder Value'],
#  ['IMMR',
#   'Apr-23-20',
#   '04:15PM',
#   'Immersion to Report First Quarter 2020 Results and Host Quarterly Conference Call on May 7, 2020'],
#  ['IMMR',
#   'Apr-23-20',
#   '08:30AM',
#   'Immersion and Alps Alpine Announce a New Level of Partnership With Active Sensing Technology License'],
#  ['IMMR',
#   'Mar-30-20',
#   '08:37AM',
#   "Did Changing Sentiment Drive Immersion's (NASDAQ:IMMR) Share Price Down By 44%?"],
#  ['IMMR',
#   'Mar-26-20',
#   '10:17AM',
#   'Edited Transcript of IMMR earnings conference call or presentation 5-Mar-20 10:00pm GMT'],
#  ['IMMR',
#   'Mar-19-20',
#   '01:30PM',
#   'Gaithersburg biotech gets green light for superbug therapy, explores COVID-19 vaccine production'],
#  ['FB',
#   'Mar-24-22',
#   '11:44PM',
#   'Instacart Slashes Its Valuation by Almost 40% to $24 Billion'],
#  ['FB',
#   'Mar-24-22',
#   '08:47PM',
#   'UPDATE 1-Meta inks partnership for 3D ads in step toward the metaverse'],
#  ['FB',
#   'Mar-24-22',
#   '07:23PM',
#   'EU Approves Controversial New Law Putting Clamps on Big Tech'],
#  ['FB',
#   'Mar-24-22',
#   '07:10PM',
#   'These Are The 5 Best Stocks To Buy And Watch Now'],
#  ['FB',
#   'Mar-24-22',
#   '04:32PM',
#   'Facebook Receives Very Bad News From Small Businesses'],
#  ['FB',
#   'Mar-24-22',
#   '03:43PM',
#   'Apples Privacy Changes Crushed Facebook. But Roku Could Find an Opportunity.'],
#  ['FB',
#   'Mar-24-22',
#   '03:17PM',
#   'Why Meta Platforms Stock Climbed Higher on Thursday'],
#  ['FB',
#   'Mar-24-22',
#   '02:51PM',
#   "Amazon's profits will be hammered by higher gas prices: top analyst"],
#  ['FB',
#   'Mar-24-22',
#   '02:03PM',
#   'Musk and Zuckerberg Fail to Make Cut in High Character CEO ETF'],
#  ['FB',
#   'Mar-24-22',
#   '01:45PM',
#   'NATO Boosts Forces in East Amid Chemical Incidents Warning'],
#  ['FB',
#   'Mar-24-22',
#   '01:34PM',
#   '10 Cryptocurrencies To Buy and Hold for the Next 10 Years'],
#  ['FB',
#   'Mar-24-22',
#   '12:55PM',
#   'SNAP Acquires NextMind to Drive Augmented Reality Research'],
#  ['FB',
#   'Mar-24-22',
#   '12:35PM',
#   'Meta, Formerly Facebook, Files 8 Crypto Trade Applications'],
#  ['FB',
#   'Mar-24-22',
#   '11:52AM',
#   'Google Denies It Included Lawyers on Emails to Dodge Regulator Scrutiny'],
#  ['FB',
#   'Mar-24-22',
#   '11:39AM',
#   'Top Meta Platforms Execs Go Remote. Where Are They Headed?'],
#  ['FB',
#   'Mar-24-22',
#   '11:12AM',
#   'Meta announces $800 million data center near Kansas City airport'],
#  ['FB',
#   'Mar-24-22',
#   '10:26AM',
#   "Execu-dus? Meta's top leaders are scattering far from Silicon Valley"],
#  ['FB',
#   'Mar-24-22',
#   '10:25AM',
#   'Barbara Corcoran: The key to understanding celebrity CEOs like Elon Musk and Mark Zuckerberg'],
#  ['FB',
#   'Mar-24-22',
#   '10:06AM',
#   'Meta Trades Like Value Stock After $500 Billion Rout'],
#  ['FB',
#   'Mar-24-22',
#   '09:49AM',
#   'The difference between Mark Zuckerberg and Elon Musk'],
#  ['FB',
#   'Mar-24-22',
#   '09:34AM',
#   '3D ads come to Facebook, Instagram in step toward the metaverse'],
#  ['FB',
#   'Mar-24-22',
#   '06:00AM',
#   'Influencers with Andy Serwer: Barbara Corcoran'],
#  ['FB',
#   'Mar-24-22',
#   '05:59AM',
#   'How investors can navigate surging inflation'],
#  ['FB', 'Mar-24-22', '05:02AM', "How Block's Cash App Makes Money"],
#  ['FB',
#   'Mar-23-22',
#   '08:23PM',
#   'Facebook Promises Change But It Is Stained by Hate Speech'],
#  ['FB',
#   'Mar-23-22',
#   '05:45PM',
#   'Meta Platforms (FB) Dips More Than Broader Markets: What You Should Know'],
#  ['FB',
#   'Mar-23-22',
#   '04:19PM',
#   'Facebook Wants to Change But Is Stained by Hate Speech'],
#  ['FB',
#   'Mar-23-22',
#   '02:55PM',
#   'Meta Stock May Be Ready To Pause; Why This Butterfly Spread Trade Could Earn 20%'],
#  ['FB',
#   'Mar-23-22',
#   '02:52PM',
#   'Metaverse presents half a trillion-dollar opportunity: ProShares strategist'],
#  ['FB',
#   'Mar-23-22',
#   '02:40PM',
#   'Meta to Enter Crypto With Trading and Metaverse Trademark Applications'],
#  ['FB',
#   'Mar-23-22',
#   '11:08AM',
#   'Instagram to Allow Users to See Most Recent Posts First'],
#  ['FB',
#   'Mar-23-22',
#   '10:57AM',
#   'PacifiCorp plots new path to deliver green energy to big customers'],
#  ['FB',
#   'Mar-23-22',
#   '10:38AM',
#   'Is Roblox Stock A Buy Right Now After Hitting All-Time Lows?'],
#  ['FB',
#   'Mar-23-22',
#   '07:15AM',
#   'Tencent Declares Reckless Era for Tech Is Over as Growth Tanks'],
#  ['FB',
#   'Mar-22-22',
#   '04:43PM',
#   'Facebook Parent Meta Completes Over\xa0Half\xa0of Recommended Civil Rights Measures'],
#  ['FB',
#   'Mar-22-22',
#   '04:29PM',
#   'The yield curve is scaring the bajeezus out of most investors, strategist says'],
#  ['FB',
#   'Mar-22-22',
#   '03:47PM',
#   'Ex-Atlanta Mayor Weighs\xa0Political Moves: Equality Summit Update'],
#  ['FB',
#   'Mar-22-22',
#   '03:42PM',
#   'Block stock pops, Carnival Cruise Line misses on earnings, Facebook users reportedly leave platform'],
#  ['FB',
#   'Mar-22-22',
#   '03:26PM',
#   'Tech companies have nimble margins amid inflation, strategist says'],
#  ['FB',
#   'Mar-22-22',
#   '02:39PM',
#   'Facebook Continues To Lose Out On User Time; Netherlands Data Center Plans Face Opposition'],
#  ['FB',
#   'Mar-22-22',
#   '12:36PM',
#   "Meta's plans to build Dutch data centre hit political glitch"],
#  ['FB',
#   'Mar-22-22',
#   '12:21PM',
#   'YouTube at Risk of Russia Ban After Facebook Deemed Illegal'],
#  ['FB',
#   'Mar-22-22',
#   '11:42AM',
#   'Metas Mega Data Center Faces Pushback in the Netherlands'],
#  ['FB',
#   'Mar-22-22',
#   '11:42AM',
#   'Meta Platforms (FB) Sued by Australian Authorities Over Fake Ads'],
#  ['FB',
#   'Mar-22-22',
#   '09:00AM',
#   'Tech Billionaires Rally Around Nuclear as Energy Crisis Looms'],
#  ['FB',
#   'Mar-22-22',
#   '05:00AM',
#   'Build A Massive Facebook Audience With This Marketing Bundle'],
#  ['FB',
#   'Mar-22-22',
#   '01:43AM',
#   'Russia court bans Facebook, Instagram for extremism  but spares WhatsApp'],
#  ['FB',
#   'Mar-22-22',
#   '12:00AM',
#   'Roundhill Ball Metaverse UCITS ETF (METV) Launches in Germany'],
#  ['FB',
#   'Mar-21-22',
#   '11:52PM',
#   'Facebook failed to detect hate speech, calls to violence in Myanmar, report finds'],
#  ['FB',
#   'Mar-21-22',
#   '04:24PM',
#   'Russian court bans Facebook, Instagram for extremist activities'],
#  ['FB',
#   'Mar-21-22',
#   '03:28PM',
#   'MemeMarkets: Meet the Metaverse ETF that is shorting Meta'],
#  ['FB',
#   'Mar-21-22',
#   '03:24PM',
#   'Market check: Stocks fall as oil extends gains'],
#  ['FB',
#   'Mar-21-22',
#   '01:57PM',
#   'Facebook sued by Australian watchdog over fake celebrity ads'],
#  ['FB',
#   'Mar-21-22',
#   '12:48PM',
#   'Russia imposes second ban on Facebook for extremist activity'],
#  ['FB',
#   'Mar-21-22',
#   '12:16PM',
#   'Russia Bans Facebook and Instagram Under Extremism Law'],
#  ['FB',
#   'Mar-21-22',
#   '10:50AM',
#   'Meta struggles to retain talent amid falling stock price'],
#  ['FB',
#   'Mar-21-22',
#   '10:18AM',
#   'Russias Invasion Is\xa0Accelerating Splinternet, French Envoy Says'],
#  ['FB',
#   'Mar-21-22',
#   '10:10AM',
#   "Josh Peck describes new memoir as 'most millennial thing I could ever do'"],
#  ['FB', 'Mar-21-22', '08:56AM', 'Where Will Meta Platforms Be in 3 Years?'],
#  ['FB',
#   'Mar-21-22',
#   '08:51AM',
#   'Is Meta Platforms (FB) Still a Worthy Investment Choice?'],
#  ['FB',
#   'Mar-21-22',
#   '08:41AM',
#   'Is it Still Safe to Own Meta Platforms (FB) Shares?'],
#  ['FB',
#   'Mar-21-22',
#   '08:14AM',
#   'Digital advertising: companies reliant on behavioural technology need new workarounds'],
#  ['FB',
#   'Mar-21-22',
#   '08:00AM',
#   "'Dip Buyers' Make Big Money On 10 Bouncing Stocks (For Now)"],
#  ['FB',
#   'Mar-21-22',
#   '07:50AM',
#   "UPDATE 4-Russia finds Meta guilty of 'extremist activity', says WhatsApp can stay"],
#  ['FB',
#   'Mar-21-22',
#   '05:06AM',
#   "10 Stocks I've Bought During the Market Sell-Off"],
#  ['FB',
#   'Mar-21-22',
#   '04:49AM',
#   "Russia labels Meta an 'extremist organisation', says WhatsApp can stay"],
#  ['FB',
#   'Mar-21-22',
#   '04:16AM',
#   "Meta asks Russian court to dismiss proceedings in 'extremism' case - reports"],
#  ['FB',
#   'Mar-20-22',
#   '09:18AM',
#   'Instagram finally has parental controls. Heres how to use them'],
#  ['FB', 'Mar-20-22', '07:00AM', '3 Stocks to Buy Before They Skyrocket Again'],
#  ['FB', 'Mar-20-22', '06:30AM', 'Meta Platforms Stock: Bear vs. Bull'],
#  ['FB',
#   'Mar-19-22',
#   '07:11PM',
#   'Brazil Bans\xa0Telegram Messaging Service in Crackdown on Fake News'],
#  ['FB', 'Mar-19-22', '09:00AM', 'Better Buy: Meta Platforms vs. Nvidia'],
#  ['FB',
#   'Mar-19-22',
#   '07:15AM',
#   'Beyond Stock Splits and Interest Rates: 3 Beaten-Down Growth Stocks to Buy Right Now'],
#  ['FB',
#   'Mar-19-22',
#   '05:57AM',
#   '2 Metaverse Stocks That Could Double, According to Wall Street'],
#  ['FB',
#   'Mar-18-22',
#   '07:02PM',
#   'Facebook Is Still Struggling. TikTok Wont Be the Only Beneficiary.'],
#  ['FB',
#   'Mar-18-22',
#   '04:40PM',
#   'Russian copycats are stealing intellectual property of American brands'],
#  ['FB',
#   'Mar-18-22',
#   '03:18PM',
#   'Stocks turn positive to end the week, led by megacap sectors'],
#  ['FB',
#   'Mar-18-22',
#   '01:45PM',
#   "McDonald's, Starbucks, and others have no recourse for stolen trademarks in Russia"],
#  ['FB',
#   'Mar-18-22',
#   '12:00PM',
#   'Instagram users targeted for get-rich-quick investment scams'],
#  ['FB',
#   'Mar-18-22',
#   '11:54AM',
#   'Instagram releases new parental supervisory tools: What to know'],
#  ['FB',
#   'Mar-18-22',
#   '10:56AM',
#   'Warren Buffett Stocks: Alphabet, Microsoft Among 26 Stocks On This Screen'],
#  ['FB',
#   'Mar-18-22',
#   '10:24AM',
#   'Meta (FB) Introduces Parental Supervision in Instagram and VR'],
#  ['FB',
#   'Mar-18-22',
#   '10:02AM',
#   'Alphabet (GOOGL) to Boost AR Efforts With Raxium Acquisition'],
#  ['FB',
#   'Mar-18-22',
#   '09:00AM',
#   'ON Semiconductor and Meta Platforms have been highlighted as Zacks Bull and Bear of the Day'],
#  ['FB', 'Mar-18-22', '05:00AM', 'Bear of the Day: Meta Platforms, Inc. (FB)'],
#  ['FB',
#   'Mar-18-22',
#   '01:35AM',
#   'Meta sued by Australian regulator for allegedly misleading crypto ads'],
#  ['FB',
#   'Mar-17-22',
#   '08:00PM',
#   'Meta Sued by Australian Watchdog Over Scam Crypto Advertisements'],
#  ['FB',
#   'Mar-17-22',
#   '07:41PM',
#   'Australian watchdog sues Facebook-owner Meta over scam advertisements'],
#  ['FB',
#   'Mar-17-22',
#   '07:35PM',
#   'UPDATE 2-Australian watchdog sues Facebook-owner Meta over scam advertisements'],
#  ['FB',
#   'Mar-17-22',
#   '05:48PM',
#   'Amazons FTC Nemesis Is Dealt a Setback on MGM Deal -- for Now'],
#  ['FB',
#   'Mar-17-22',
#   '05:12PM',
#   'Meta suspends Kanye West from Instagram for racist slur towards comedian Trevor Noah'],
#  ['FB',
#   'Mar-17-22',
#   '04:52PM',
#   'Why one analyst is pushing to buy oversold tech stocks like Apple'],
#  ['FB',
#   'Mar-17-22',
#   '01:46PM',
#   "Here's what Warren Buffett's favorite stock market indicator is saying now"],
#  ['FB',
#   'Mar-17-22',
#   '01:13PM',
#   'Buy oversold tech stocks, especially Apple: Analyst'],
#  ['FB',
#   'Mar-17-22',
#   '12:59PM',
#   'Mark Zuckerberg May Get Leapfrogged Into the Metaverse'],
#  ['FB',
#   'Mar-17-22',
#   '10:47AM',
#   'Robinhood prepares stock lending program, Instagram bans Kanye, Tesla hikes Model Y price in China'],
#  ['FB',
#   'Mar-17-22',
#   '10:46AM',
#   'Market strategist talks stocks, investing amid rising rates, and the metaverse ETF'],
#  ['FB',
#   'Mar-17-22',
#   '10:03AM',
#   'Meta to test content tools for advertisers later this year'],
#  ['FB',
#   'Mar-17-22',
#   '10:00AM',
#   'Meta to test content tools for advertisers later this year'],
#  ['FB', 'Mar-17-22', '10:00AM', 'Is AMD Stock a Buy Now?'],
#  ['U',
#   'Mar-23-22',
#   '05:45PM',
#   'Unity Software Inc. (U) Gains As Market Dips: What You Should Know'],
#  ['U',
#   'Mar-23-22',
#   '02:52PM',
#   'Metaverse presents half a trillion-dollar opportunity: ProShares strategist'],
#  ['U',
#   'Mar-22-22',
#   '10:00AM',
#   'Unity Appoints Michelle K. Lee to Board of Directors'],
#  ['U', 'Mar-22-22', '08:27AM', '2 Reasons I Just Bought Unity Software'],
#  ['U',
#   'Mar-20-22',
#   '11:30AM',
#   'This Gaming Stock Is Expanding Into Even More Industries'],
#  ['U',
#   'Mar-19-22',
#   '07:15AM',
#   'Beyond Stock Splits and Interest Rates: 3 Beaten-Down Growth Stocks to Buy Right Now'],
#  ['U',
#   'Mar-19-22',
#   '05:57AM',
#   '2 Metaverse Stocks That Could Double, According to Wall Street'],
#  ['U', 'Mar-18-22', '08:09AM', 'Is Now the Time to Buy Unity Stock?'],
#  ['U',
#   'Mar-17-22',
#   '10:46AM',
#   '2 Best Metaverse Stocks To Buy in 2022 and Beyond'],
#  ['U',
#   'Mar-17-22',
#   '08:57AM',
#   '2 Metaverse Stocks to Buy if the Market Crashes Further'],
#  ['U',
#   'Mar-16-22',
#   '08:00AM',
#   'Gaming Poised to Continue Accelerated Growth According to Unity Gaming Report 2022'],
#  ['U', 'Mar-15-22', '12:22PM', '3 Metaverse Stocks That Might Interest You'],
#  ['U',
#   'Mar-15-22',
#   '10:46AM',
#   'Here\'s Why I Just Bought This "Expensive" Growth Stock'],
#  ['U',
#   'Mar-13-22',
#   '09:11AM',
#   '2 Unstoppable Stocks That Could Turn $50,000 Into $250,000 by 2030'],
#  ['U',
#   'Mar-12-22',
#   '07:20AM',
#   '2 Stocks I Will Buy If the Stock Market Keeps Crashing'],
#  ['U', 'Mar-11-22', '07:00AM', '3 Stocks I Bought This Week'],
#  ['U',
#   'Mar-11-22',
#   '04:00AM',
#   'Unity Announces New Partnership with Insomniac Events'],
#  ['U',
#   'Mar-10-22',
#   '06:10PM',
#   '7 Cathie Wood Stocks That Are Worth Buying in March'],
#  ['U',
#   'Mar-10-22',
#   '06:05PM',
#   '7 Web 3.0 Stocks to Buy for Their First-Mover Advantage'],
#  ['U',
#   'Mar-10-22',
#   '07:20AM',
#   'Will Unity Software Be a Trillion-Dollar Stock by 2040?'],
#  ['U',
#   'Mar-09-22',
#   '07:50AM',
#   '2 Monster Metaverse Stocks to Buy for the Long Haul'],
#  ['U',
#   'Mar-07-22',
#   '07:45AM',
#   '3 Unstoppable Metaverse Stocks With Monster Upside'],
#  ['U',
#   'Mar-04-22',
#   '02:56PM',
#   "Time to Make a 'U' Turn If You're Headed Toward Unity Software"],
#  ['U',
#   'Mar-01-22',
#   '11:59AM',
#   '7 Metaverse Stocks to Make a Move on Right Now'],
#  ['U', 'Mar-01-22', '10:03AM', 'Is Unity Software Stock a Buy Now?'],
#  ['U', 'Mar-01-22', '07:07AM', '2 Top Stocks in Creativity Worth Considering'],
#  ['U',
#   'Feb-26-22',
#   '06:15AM',
#   '2 Stocks That I Am Keeping My Eyes on During This Correction'],
#  ['U',
#   'Feb-24-22',
#   '07:51AM',
#   'Have $1,000? These 2 Stocks Could Be Bargain Buys for 2022 and Beyond'],
#  ['U', 'Feb-24-22', '07:10AM', 'Could Unity Become The Next Adobe?'],
#  ['U', 'Feb-22-22', '09:03AM', 'Could Unity Software Become the Next Apple?'],
#  ['U',
#   'Feb-22-22',
#   '07:35AM',
#   '2 Disruptive Metaverse Stocks to Buy and Hold for the Next 10 Years'],
#  ['U',
#   'Feb-22-22',
#   '05:15AM',
#   'Unity Software May Be the Stock of the Decade, Judging by This Metric'],
#  ['U',
#   'Feb-21-22',
#   '10:30AM',
#   '5 Stocks That Could Turn $50,000 Into $1 Million by 2040'],
#  ['U',
#   'Feb-21-22',
#   '07:16AM',
#   '10 Stocks to Invest In According to Carl Andersons Marcho Partners'],
#  ['U',
#   'Feb-20-22',
#   '07:15AM',
#   'Tech Sell-Off: 3 No-Brainer Stocks to Buy Right Now'],
#  ['U',
#   'Feb-20-22',
#   '07:15AM',
#   "Given Unity's Incredible Growth, Is the Rich Valuation Worth It?"],
#  ['U',
#   'Feb-19-22',
#   '11:30AM',
#   "'Scary Realistic:' What Unity's Latest Acquisition Means for Its Future"],
#  ['U', 'Feb-19-22', '08:15AM', 'This Gaming Stock Could 13X in 10 Years'],
#  ['U',
#   'Feb-19-22',
#   '06:45AM',
#   "'Huge Potential' for This Popular Stock Beyond Its Core Gaming Realm"],
#  ['U',
#   'Feb-16-22',
#   '04:37PM',
#   'Roblox Tumbles Most Ever as Results Take Hit After Pandemic'],
#  ['U',
#   'Feb-15-22',
#   '06:15AM',
#   '2 Hypergrowth Stocks to Buy in 2022 and Beyond'],
#  ['U',
#   'Feb-14-22',
#   '08:35AM',
#   'Got $5,000? These Are 2 of the Best Growth Stocks to Buy Right Now'],
#  ['U', 'Feb-12-22', '09:07AM', 'Where Will Unity Software Be in 5 Years?'],
#  ['U',
#   'Feb-11-22',
#   '02:16PM',
#   '7 Tech Stocks Set for Strong Gains in February'],
#  ['U',
#   'Feb-11-22',
#   '07:20AM',
#   '3 Breakout Growth Stocks You Can Buy and Hold for the Next Decade'],
#  ['U',
#   'Feb-10-22',
#   '11:55AM',
#   'Cathie Woods Ark Invest files to to launch venture fund'],
#  ['U',
#   'Feb-10-22',
#   '11:38AM',
#   "3 Reasons I'm Ready to Buy More Unity Stock After Its Q4 report"],
#  ['U', 'Feb-10-22', '09:25AM', 'Unity Stock: Bear vs. Bull'],
#  ['U',
#   'Feb-10-22',
#   '07:54AM',
#   "1 Smart Pick-and-Shovel Play on the Internet's Future"],
#  ['U',
#   'Feb-09-22',
#   '10:09AM',
#   'CEOs of Matterport, Liquid Avatar, Unity and ESE Entertainment Targeting Billion Dollar Market Opportunities and Explosive Revenue Growth in the Metaverse and Digital Entertainment.'],
#  ['U',
#   'Feb-09-22',
#   '09:21AM',
#   'Tech Sell-Off: 1 Growth Stock To Buy, and 1 To Sell'],
#  ['U', 'Feb-09-22', '07:53AM', 'Is It Too Late to Buy Unity Software Stock?'],
#  ['U',
#   'Feb-08-22',
#   '08:12PM',
#   "Unity Software Inc.'s (NYSE:U) Development Needs More Work and is Pressured by Competitors - A Qualitative Analysis"],
#  ['U',
#   'Feb-08-22',
#   '01:38PM',
#   'Windmill Hill Asset Management Ltd Buys Airbnb Inc, Unity Software Inc, Blend Labs Inc, Sells ...'],
#  ['U',
#   'Feb-08-22',
#   '01:38PM',
#   'Biondo Investment Advisors, LLC Buys Unity Software Inc, Coinbase Global Inc, PNC Financial ...'],
#  ['U',
#   'Feb-08-22',
#   '10:15AM',
#   'This Is Why Unity Software Is More Than Just a Metaverse Stock'],
#  ['U',
#   'Feb-08-22',
#   '09:38AM',
#   'Lyell Wealth Management, Lp Buys Cloudflare Inc, Unity Software Inc, Morgan Stanley, Sells ...'],
#  ['U', 'Feb-08-22', '08:47AM', '1 Great Tech Stock to Buy Now'],
#  ['U',
#   'Feb-07-22',
#   '09:38AM',
#   'Aviance Capital Partners, LLC Buys ASML Holding NV, Unity Software Inc, Linde PLC, Sells ...'],
#  ['U',
#   'Feb-06-22',
#   '03:53PM',
#   'Were Expert Investors Right About Unity Software Inc. (U)?'],
#  ['U',
#   'Feb-06-22',
#   '01:48PM',
#   '10 Stocks Making Headlines Following Earnings Reports'],
#  ['U', 'Feb-05-22', '10:00AM', "Unity Stock Crushed It Again, What's Next?"],
#  ['U',
#   'Feb-04-22',
#   '05:38PM',
#   'Tandem Capital Management Corp  Buys PerkinElmer Inc, Altra Industrial Motion Corp, Autodesk ...'],
#  ['U',
#   'Feb-04-22',
#   '05:09PM',
#   '4 Top Stock Trades for Monday: Bitcoin, Ethereum, U, AMZN'],
#  ['U',
#   'Feb-04-22',
#   '04:16PM',
#   'Unity Software Stock Rockets On Beat-And-Raise Fourth-Quarter Report'],
#  ['U',
#   'Feb-04-22',
#   '04:03PM',
#   'Stocks to watch: Clorox, Unity Software, Salesforce, Southwest Airlines'],
#  ['U',
#   'Feb-04-22',
#   '03:17PM',
#   'Unity Software Stock Soared Today -- Is It a Buy?'],
#  ['U', 'Feb-04-22', '01:08PM', 'Why Unity Software Stock Popped Today'],
#  ['U',
#   'Feb-04-22',
#   '11:56AM',
#   'Unity Software Stock Is Soaring as 2022 Revenue Forecast Tops Estimates'],
#  ['U',
#   'Feb-04-22',
#   '10:21AM',
#   'U Stock: 16 Things to Know About Video Game Design Player Unity Software'],
#  ['U',
#   'Feb-04-22',
#   '09:38AM',
#   'Gainplan LLC Buys iShares Russell 1000 Growth ETF, PowerShares QQQ Trust Ser 1, Lightspeed ...'],
#  ['U',
#   'Feb-04-22',
#   '08:33AM',
#   'Why Unity Stock Plunged Almost 27% Last Month'],
#  ['U',
#   'Feb-04-22',
#   '07:47AM',
#   'Unity Software Surges as It Sees Strong Momentum Sustaining'],
#  ['U', 'Feb-04-22', '05:50AM', '4 Growth Stocks to Buy and Hold Forever'],
#  ['U',
#   'Feb-03-22',
#   '06:15PM',
#   'Unity Software Inc. (U) Reports Q4 Loss, Tops Revenue Estimates'],
#  ['U',
#   'Feb-03-22',
#   '04:05PM',
#   'Unity Announces Fourth Quarter and Full Year 2021 Financial Results'],
#  ['U',
#   'Feb-03-22',
#   '12:12PM',
#   'Unity Gains as Q4 Earnings, Revenue Beat Expectations'],
#  ['U', 'Feb-03-22', '10:48AM', 'All Eyes Will Be on These 5 Earnings Charts'],
#  ['U',
#   'Feb-03-22',
#   '09:38AM',
#   'JNBA Financial Advisors Buys Schwab Fundamental International Large Company Ind, Avantis ...'],
#  ['U', 'Feb-02-22', '07:35AM', 'This Is the Only Metaverse Stock You Need'],
#  ['U', 'Feb-02-22', '06:58AM', 'We Dodged a Bullet With Unity Software'],
#  ['U',
#   'Feb-01-22',
#   '10:00AM',
#   'Growth Investors Should Watch These 2 Earnings This Week'],
#  ['U',
#   'Jan-31-22',
#   '05:38PM',
#   'Gratus Capital LLC Buys Fidelity Total Bond ETF, Unity Software Inc, Elastic NV, Sells Vanguard ...'],
#  ['U',
#   'Jan-31-22',
#   '09:38AM',
#   'LifePro Asset Management Buys The Trade Desk Inc, Roblox Corp, MongoDB Inc, Sells Occidental ...'],
#  ['U',
#   'Jan-29-22',
#   '09:10AM',
#   '2 Breakout Growth Stocks You Can Buy and Hold for the Next Decade'],
#  ['U',
#   'Jan-28-22',
#   '05:45PM',
#   'Unity Software Inc. (U) Gains But Lags Market: What You Should Know'],
#  ['U',
#   'Jan-28-22',
#   '01:38PM',
#   'Hamilton Lane Advisors Llc Buys Monday.Com, Boxed Inc, Dun & Bradstreet Holdings Inc, Sells ...'],
#  ['U',
#   'Jan-28-22',
#   '08:37AM',
#   '2 Top Metaverse Stocks to Buy and Hold for the Next 10 Years'],
#  ['U',
#   'Jan-27-22',
#   '03:01PM',
#   'Unity Software Inc. (U) Expected to Beat Earnings Estimates: What to Know Ahead of Q4 Release'],
#  ['U',
#   'Jan-27-22',
#   '01:04PM',
#   '7 Metaverse Stocks That Future-Thinking Investors Need to Know About'],
#  ['U',
#   'Jan-27-22',
#   '09:40AM',
#   'Unity Software Down Despite Being Added to Best Ideas List'],
#  ['U',
#   'Jan-27-22',
#   '09:40AM',
#   '4 Stock Winners and 4 Losers in the Microsoft-Activision Deal'],
#  ['U',
#   'Jan-27-22',
#   '06:20AM',
#   '3 Stocks To Buy Before Their Next Earnings Reports'],
#  ['U', 'Jan-27-22', '05:55AM', 'Better Metaverse Stock: Nvidia or Unity?'],
#  ['U',
#   'Jan-26-22',
#   '05:38PM',
#   'Kercheville Advisors, LLC Buys The Carlyle Group Inc, Hess Midstream LP, Consumer Staples ...'],
#  ['U', 'Jan-26-22', '07:00AM', "Why I Like Unity Software's New Acquisition"],
#  ['U',
#   'Jan-24-22',
#   '05:38PM',
#   'Highland Private Wealth Management Buys iShares MSCI EAFE ESG Select ETF, iShares MSCI USA ESG ...'],
#  ['U',
#   'Jan-24-22',
#   '11:03AM',
#   'Unity Acquires Character Design Firm Ziva Dynamics'],
#  ['U',
#   'Jan-24-22',
#   '09:38AM',
#   'Regents Of The University Of California Buys Unity Software Inc, Airbnb Inc, QuantumScape Corp, ...'],
#  ['U',
#   'Jan-24-22',
#   '07:15AM',
#   'Down 38% to 51%: 3 Top Metaverse Stocks to Buy for 2022 and Beyond'],
#  ['NVDA',
#   'Mar-25-22',
#   '01:09AM',
#   'Dow Jones Futures: Market Rallies As Nvidia, AMD Lead Chip Surge; Nio Earnings Mixed'],
#  ['NVDA',
#   'Mar-24-22',
#   '07:36PM',
#   'These 3 Gaming Stocks Are Set To Climb the Leaderboards'],
#  ['NVDA',
#   'Mar-24-22',
#   '07:00PM',
#   "Cramer's Mad Money Recap 3/24: Intel, Marvell, Nvidia"],
#  ['NVDA',
#   'Mar-24-22',
#   '04:46PM',
#   'Nvidia CEO Jensen Huang: Our Grace CPU is a new growth market'],
#  ['NVDA',
#   'Mar-24-22',
#   '04:18PM',
#   'Nvidia Jumps, Lifting Nearly All Other U.S. Stocks on Growth Bet'],
#  ['NVDA',
#   'Mar-24-22',
#   '04:16PM',
#   '3 Top S&P 500 Stock Market Gainers Today: Nvidia Headlines Semiconductor Advance'],
#  ['NVDA', 'Mar-24-22', '03:34PM', 'Market check: Tech leads stocks higher'],
#  ['NVDA',
#   'Mar-24-22',
#   '03:27PM',
#   'Dow trades 300 points higher as Biden touts NATO response to Russia-Ukraine war, Fed speakers'],
#  ['NVDA',
#   'Mar-24-22',
#   '03:18PM',
#   "Goldman Sachs poised to lead U.S. IPO of SoftBank's Arm - sources"],
#  ['NVDA',
#   'Mar-24-22',
#   '03:11PM',
#   'Dow Jones Gains As Biden Warns Putin; Nvidia Leads Chip Stocks Higher'],
#  ['NVDA',
#   'Mar-24-22',
#   '03:08PM',
#   'Why Intel, AMD, and Navitas Stocks Popped Thursday'],
#  ['NVDA',
#   'Mar-24-22',
#   '01:56PM',
#   'Oxford teen accused of making more than £10m as a leader of international cyber gang'],
#  ['NVDA',
#   'Mar-24-22',
#   '01:23PM',
#   'Rivals Nvidia and Intel Might Join Forces To End Chip Shortage'],
#  ['NVDA', 'Mar-24-22', '12:47PM', 'Why Nvidia Stock Finally Popped Today'],
#  ['NVDA',
#   'Mar-24-22',
#   '10:44AM',
#   'S&P 500 Climbs on Bullish Bets Powered by Chip Stocks'],
#  ['NVDA', 'Mar-24-22', '10:41AM', 'Nvidia CEO: Hack was a wake-up call'],
#  ['NVDA',
#   'Mar-24-22',
#   '09:11AM',
#   'Is Most-Watched Stock NVIDIA Corporation (NVDA) Worth Betting on Now?'],
#  ['NVDA',
#   'Mar-24-22',
#   '08:55AM',
#   'Nvidia Announces 3 New Powerful AI Chips -- What Investors Need to Know'],
#  ['NVDA',
#   'Mar-24-22',
#   '07:52AM',
#   'Hackers Against Okta, Microsoft, NVIDIA Traced To England, Brazil: Bloomberg'],
#  ['NVDA',
#   'Mar-23-22',
#   '06:15PM',
#   'Nvidia: Primed to Win in the AI Space but Valuation Is Running Hot, Says Analyst'],
#  ['NVDA',
#   'Mar-23-22',
#   '05:53PM',
#   'Yahoo Finance Presents: Nvidia Founder & CEO Jensen Huang'],
#  ['NVDA', 'Mar-23-22', '04:54PM', 'Why Vicor Shares Powered Off Today'],
#  ['NVDA',
#   'Mar-23-22',
#   '02:52PM',
#   'Metaverse presents half a trillion-dollar opportunity: ProShares strategist'],
#  ['NVDA',
#   'Mar-23-22',
#   '01:06PM',
#   '10 Finance Stocks to Invest In According to Paul Tudor Joness Tudor Investment Corp'],
#  ['NVDA',
#   'Mar-23-22',
#   '12:54PM',
#   'Nvidias $1 trillion ambitions draw cheers as software becomes a bigger piece of the pie'],
#  ['NVDA',
#   'Mar-23-22',
#   '12:13PM',
#   'Nvidia CEO says interested in exploring chip manufacturing with Intel'],
#  ['NVDA',
#   'Mar-23-22',
#   '12:04PM',
#   'UPDATE 2-Nvidia CEO says interested in exploring chip manufacturing with Intel'],
#  ['NVDA', 'Mar-23-22', '11:21AM', 'Why Nvidia Stock Dropped Today'],
#  ['NVDA', 'Mar-23-22', '11:13AM', 'Nvidias Trillion Dollar Dreams'],
#  ['NVDA',
#   'Mar-23-22',
#   '10:38AM',
#   'Is Roblox Stock A Buy Right Now After Hitting All-Time Lows?'],
#  ['NVDA',
#   'Mar-23-22',
#   '10:28AM',
#   'Stock Market Falls As Techs Falter, Oil Rises; This Industry Keeps Rallying'],
#  ['NVDA',
#   'Mar-23-22',
#   '10:19AM',
#   'Market check: Stocks pare gains, oil rises'],
#  ['NVDA',
#   'Mar-23-22',
#   '09:45AM',
#   'Nvidia CEO says Lapsus$ hack was a wake-up call'],
#  ['NVDA',
#   'Mar-23-22',
#   '09:14AM',
#   'Artificial Intelligence Stocks To Buy And Watch: AI Software Market Booms'],
#  ['NVDA',
#   'Mar-23-22',
#   '08:19AM',
#   'NVIDIA (NVDA) Starts Production of DRIVE Orin Platform'],
#  ['NVDA',
#   'Mar-23-22',
#   '08:17AM',
#   'Vicor Tumbles After CJS Securities Downgrade'],
#  ['NVDA',
#   'Mar-23-22',
#   '06:20AM',
#   'Is SPDR NYSE Technology ETF (XNTK) a Strong ETF Right Now?'],
#  ['NVDA',
#   'Mar-22-22',
#   '05:19PM',
#   '10 Precious Metals Stocks to Buy According to Ken Fisher'],
#  ['NVDA',
#   'Mar-22-22',
#   '03:16PM',
#   'Kroger Partners With NVIDIA For AI Services'],
#  ['NVDA',
#   'Mar-22-22',
#   '03:15PM',
#   'Market check: Stocks move higher, Tesla stock surges, Nvidia shares fall'],
#  ['NVDA',
#   'Mar-22-22',
#   '01:15PM',
#   'TSMC Sees Demand Spike For Auto Chips Thanks To Tesla, Nvidia, Qualcomm, Intel'],
#  ['NVDA',
#   'Mar-22-22',
#   '01:00PM',
#   'Nvidia teams up with Lucid and BYD for new self-driving platform'],
#  ['NVDA',
#   'Mar-22-22',
#   '01:00PM',
#   'Nvidia debuts new Arm-based Grace CPU superchip'],
#  ['NVDA',
#   'Mar-22-22',
#   '01:00PM',
#   'NVIDIA Launches Omniverse for Developers: A Powerful and Collaborative Game Creation Environment'],
#  ['NVDA',
#   'Mar-22-22',
#   '12:38PM',
# ...
#   '11:38AM',
#   "What's in Store for One Stop Systems' (OSS) Q4 Earnings?"],
#  ['AAPL',
#   'Mar-22-22',
#   '11:09AM',
#   'UPDATE 1-Apple, WiLAN settle patent disputes with license agreement'],
#  ['AAPL',
#   'Mar-22-22',
#   '10:55AM',
#   'Apple App Store faces new laws from global regulators'],
#  ['AAPL',
#   'Mar-22-22',
#   '09:33AM',
#   'Bernstein Explains How Apple Could Produce $10B In Incremental Revenue'],
#  ['AAPL',
#   'Mar-22-22',
#   '09:20AM',
#   'Yahoo Finance Presents: Affirm Founder Max Levchin'],
#  ['AAPL', 'Mar-22-22', '08:17AM', '3 Risks for Coinbase Stock'],
#  ['AAPL',
#   'Mar-22-22',
#   '08:00AM',
#   'Apple Podcasts to Launch Follower Metrics for Creators, Stepping Up Challenge to Spotify'],
#  ['AAPL',
#   'Mar-22-22',
#   '07:36AM',
#   'AliveCor Launches Antitrust Lawsuit Against Apple Watch: Reuters'],
#  ['AAPL',
#   'Mar-22-22',
#   '07:08AM',
#   'Apple, WiLAN settle patent disputes with license agreement'],
#  ['AAPL',
#   'Mar-22-22',
#   '07:02AM',
#   'Apple, WiLAN sign patent licensing agreement settling disputes'],
#  ['AAPL',
#   'Mar-22-22',
#   '05:30AM',
#   'Cold War 2.0? The Global Economic Impact of Sanctions Against Russia'],
#  ['AAPL',
#   'Mar-21-22',
#   '04:03PM',
#   'Apple Resolves Outage That Hobbled Apps and Internal Systems'],
#  ['AAPL',
#   'Mar-21-22',
#   '03:25PM',
#   'Millennial And Gen Z Stock Picks From Tesla To Apple: Should You Buy Them Too?'],
#  ['AAPL',
#   'Mar-21-22',
#   '02:42PM',
#   'Apple outage takes Music, App Store, TV+ and Maps offline'],
#  ['AAPL',
#   'Mar-21-22',
#   '01:43PM',
#   'UPDATE 2-Apple services including music, TV resume after outages'],
#  ['AAPL',
#   'Mar-21-22',
#   '01:27PM',
#   'Apple services including music, TV resume after outages'],
#  ['AAPL',
#   'Mar-21-22',
#   '11:48AM',
#   'How Apple Could Add $10 Billion of Revenue'],
#  ['AAPL',
#   'Mar-21-22',
#   '11:48AM',
#   'Apple Could Add $10 Billion of Revenue by Selling More Ads. Heres How.'],
#  ['AAPL',
#   'Mar-21-22',
#   '11:40AM',
#   '4 Stocks on My Radar During This Tech Sell-Off'],
#  ['AAPL',
#   'Mar-21-22',
#   '10:30AM',
#   '2 Warren Buffett Stocks to Buy and Hold if the Market Crashes'],
#  ['AAPL',
#   'Mar-21-22',
#   '10:23AM',
#   "Volkswagen's (VWAGY) Porsche Lays Out Ambitious EV Targets"],
#  ['AAPL',
#   'Mar-21-22',
#   '10:18AM',
#   'Russias Invasion Is\xa0Accelerating Splinternet, French Envoy Says'],
#  ['AAPL',
#   'Mar-21-22',
#   '10:13AM',
#   'Deal of the Day: Apple AirPods Pro hit lowest price of the year on Amazon'],
#  ['AAPL',
#   'Mar-21-22',
#   '10:03AM',
#   'Dow Jones Falls As Oil Prices, Treasury Yields Jump; Boeing Stock Slumps On Airplane Crash'],
#  ['AAPL',
#   'Mar-21-22',
#   '09:16AM',
#   "China's Smartphone Shipment Plunges By 32% In February"],
#  ['AAPL',
#   'Mar-21-22',
#   '08:42AM',
#   'Is it Still Worthy to Buy Apple (AAPL) Shares?'],
#  ['AAPL',
#   'Mar-21-22',
#   '07:14AM',
#   '3 Vanguard ETFs That Could Help You Retire a Millionaire'],
#  ['AAPL',
#   'Mar-21-22',
#   '03:00AM',
#   'I feel Apple is trying to bend the truth over my warped iPad Pro'],
#  ['AAPL',
#   'Mar-21-22',
#   '01:00AM',
#   'Korean family saga Pachinko is Apples best show so far'],
#  ['AAPL',
#   'Mar-20-22',
#   '08:44PM',
#   "UPDATE 1-Foxconn 'basically' resumes normal operations in China's Shenzhen"],
#  ['AAPL',
#   'Mar-20-22',
#   '04:31PM',
#   'U.S. charges former Apple buyer with defrauding more than $10 million from company'],
#  ['AAPL',
#   'Mar-20-22',
#   '04:26PM',
#   'U.S. charges former Apple buyer with defrauding more than $10 mln from company'],
#  ['AAPL',
#   'Mar-20-22',
#   '09:30AM',
#   '7 fitness apps beginners may want to check out'],
#  ['AAPL',
#   'Mar-20-22',
#   '09:09AM',
#   "Why Hollywood's obsessed with Silicon Valley: 'Everybody loves a rise-and-fall story'"],
#  ['AAPL',
#   'Mar-20-22',
#   '08:00AM',
#   'Just One More Reason to Be Bullish on Apple Stock'],
#  ['AAPL', 'Mar-20-22', '06:10AM', 'Apple Stock: Bear vs. Bull'],
#  ['AAPL',
#   'Mar-20-22',
#   '05:06AM',
#   '3 Tech Stocks That Can Turn $200,000 Into $1 Million in 8 Years (or Less)'],
#  ['AAPL',
#   'Mar-19-22',
#   '03:10PM',
#   'Former Apple employee charged with defrauding $10 million'],
#  ['AAPL',
#   'Mar-19-22',
#   '10:53AM',
#   '3 Resilient Stocks to Help Solidify Your Portfolio'],
#  ['MSFT',
#   'Mar-24-22',
#   '07:36PM',
#   'These 3 Gaming Stocks Are Set To Climb the Leaderboards'],
#  ['MSFT',
#   'Mar-24-22',
#   '07:23PM',
#   'EU Approves Controversial New Law Putting Clamps on Big Tech'],
#  ['MSFT',
#   'Mar-24-22',
#   '06:15PM',
#   'HPE Fuels GreenLake Expansion with Microsoft Azure Stack HCI'],
#  ['MSFT',
#   'Mar-24-22',
#   '02:40PM',
#   'I thought he was playing video games: Teenager accused of masterminding Lapsus$ hacking group'],
#  ['MSFT',
#   'Mar-24-22',
#   '01:34PM',
#   '10 Cryptocurrencies To Buy and Hold for the Next 10 Years'],
#  ['MSFT',
#   'Mar-24-22',
#   '01:26PM',
#   'U.K. Police Arrest 7 Related to Lapsus$ Hacks on Tech Firms'],
#  ['MSFT',
#   'Mar-24-22',
#   '12:19PM',
#   'UPDATE 3-Suspected Okta hackers arrested by British police'],
#  ['MSFT',
#   'Mar-24-22',
#   '10:59AM',
#   '1 Piece of Good News for Office Investors and Bad News for Tech Employees'],
#  ['MSFT', 'Mar-24-22', '10:41AM', 'Nvidia CEO: Hack was a wake-up call'],
#  ['MSFT',
#   'Mar-24-22',
#   '09:49AM',
#   'The difference between Mark Zuckerberg and Elon Musk'],
#  ['MSFT',
#   'Mar-24-22',
#   '09:27AM',
#   'Is Most-Watched Stock Microsoft Corporation (MSFT) Worth Betting on Now?'],
#  ['MSFT',
#   'Mar-24-22',
#   '07:52AM',
#   'Hackers Against Okta, Microsoft, NVIDIA Traced To England, Brazil: Bloomberg'],
#  ['MSFT',
#   'Mar-24-22',
#   '06:20AM',
#   'Should iShares Russell 1000 ETF (IWB) Be on Your Investing Radar?'],
#  ['MSFT',
#   'Mar-24-22',
#   '06:00AM',
#   '5 ETFs That Are All You Need for Retirement'],
#  ['MSFT',
#   'Mar-23-22',
#   '08:44PM',
#   'Microsoft Affected by a Cyberattack After Nvidia and Samsung'],
#  ['MSFT',
#   'Mar-23-22',
#   '08:21PM',
#   'Microsoft and Its CEO Stick to Their Choice Between Russia and Ukraine'],
#  ['MSFT',
#   'Mar-23-22',
#   '07:21PM',
#   'Google Tests\xa0Letting\xa0Apps Like Spotify Offer Own Billing'],
#  ['MSFT',
#   'Mar-23-22',
#   '05:43PM',
#   'Microsoft and Its CEO Affirm Their Choice Between Russia and Ukraine'],
#  ['MSFT',
#   'Mar-23-22',
#   '05:09PM',
#   'Teen Suspected by Cyber Researchers of Being Lapsus$ Mastermind'],
#  ['MSFT',
#   'Mar-23-22',
#   '02:52PM',
#   'Metaverse presents half a trillion-dollar opportunity: ProShares strategist'],
#  ['MSFT', 'Mar-23-22', '02:08PM', 'Why Okta Stock Was Tumbling Today'],
#  ['MSFT',
#   'Mar-23-22',
#   '01:29PM',
#   '5 Dow Jones Stocks To Buy And Watch In March 2022: Apple Jumps'],
#  ['MSFT', 'Mar-23-22', '11:55AM', 'Hackers Deal Microsoft a Big Blow'],
#  ['MSFT',
#   'Mar-23-22',
#   '10:38AM',
#   'Is Roblox Stock A Buy Right Now After Hitting All-Time Lows?'],
#  ['MSFT',
#   'Mar-23-22',
#   '10:19AM',
#   'Market check: Stocks pare gains, oil rises'],
#  ['MSFT',
#   'Mar-23-22',
#   '09:53AM',
#   'Amazon Is Back to Acting Like a Wall Street Darling'],
#  ['MSFT',
#   'Mar-23-22',
#   '09:04AM',
#   'Microsoft Says Digital Extortion Gang Lapsus$ Targets Cryptocurrency, Too'],
#  ['MSFT',
#   'Mar-23-22',
#   '08:13AM',
#   'Cadence (CDNS) to Participate in Microsoft RAMP Phase II Program'],
#  ['MSFT',
#   'Mar-23-22',
#   '08:06AM',
#   'Dow Jones Futures Fall After S&P 500 Reclaims Key Level; Apple Flashes Buy Signal'],
#  ['MSFT',
#   'Mar-23-22',
#   '05:00AM',
#   'Master Microsoft Office With This E-Learning Course'],
#  ['MSFT',
#   'Mar-22-22',
#   '08:33PM',
#   'Microsoft Confirms Hacker Group Lapsus$ Breached Its Systems'],
#  ['MSFT',
#   'Mar-22-22',
#   '03:16PM',
#   'Nvidia Unveils Data-Center Chips Aimed at Stretching Its Lead in AI'],
#  ['MSFT',
#   'Mar-22-22',
#   '09:46AM',
#   'Okta Tumbles After Hacking Group Lapsus$ Claims Data Breach'],
#  ['MSFT',
#   'Mar-22-22',
#   '09:43AM',
#   'Dow Jones Rallies As Treasury Yields Extend Gains, Nike Jumps On Earnings'],
#  ['MSFT', 'Mar-22-22', '09:35AM', 'Top 10 Blue Chip Stocks to Buy in 2022'],
#  ['MSFT', 'Mar-22-22', '09:32AM', 'Stock Market News for Mar 22, 2022'],
#  ['MSFT',
#   'Mar-22-22',
#   '09:31AM',
#   'ANSYS (ANSS) to Offer Latest EPYC Processors to Cloud Customers'],
#  ['MSFT',
#   'Mar-22-22',
#   '09:29AM',
#   '10 Cryptocurrencies Redditors Are Buying for Early Retirement'],
#  ['MSFT', 'Mar-22-22', '09:20AM', '10 Penny Stocks That Can Explode in 2022'],
#  ['MSFT',
#   'Mar-22-22',
#   '06:20AM',
#   'Is FlexShares Morningstar U.S. Market Factor Tilt ETF (TILT) a Strong ETF Right Now?'],
#  ['MSFT', 'Mar-22-22', '05:50AM', 'Why Are Okta Shares Trading Lower Today'],
#  ['MSFT',
#   'Mar-22-22',
#   '05:30AM',
#   "China asks Microsoft's Bing to pause auto-suggest feature again"],
#  ['MSFT',
#   'Mar-21-22',
#   '09:21PM',
#   'Sony Entertainment to Buy Jade Raymonds Haven Gaming Studio'],
#  ['MSFT',
#   'Mar-21-22',
#   '07:15PM',
#   'Ansys touts new collaboration with Microsoft and AMD for high-performance computing simulation improvements'],
#  ['MSFT',
#   'Mar-21-22',
#   '06:02PM',
#   'UPDATE 1-U.S. antitrust regulators seek more data from Activision, Microsoft on planned deal'],
#  ['MSFT',
#   'Mar-21-22',
#   '05:45PM',
#   'Microsoft (MSFT) Dips More Than Broader Markets: What You Should Know'],
#  ['MSFT',
#   'Mar-21-22',
#   '05:39PM',
#   'U.S. antitrust regulators seek more data from Activision, Microsoft on planned deal'],
#  ['MSFT',
#   'Mar-21-22',
#   '03:25PM',
#   'Millennial And Gen Z Stock Picks From Tesla To Apple: Should You Buy Them Too?'],
#  ['MSFT',
#   'Mar-21-22',
#   '01:18PM',
#   "Alphabet's (GOOGL) Latest Move to Boost Subsea Cable Efforts"],
#  ['MSFT',
#   'Mar-21-22',
#   '12:49PM',
#   'DXC Technology (DXC) Selected by GEFA Bank to Digitize Services'],
#  ['MSFT',
#   'Mar-21-22',
#   '10:41AM',
#   'Who will be the first trillionaire? Study predicts Elon Musk in 2024.'],
#  ['MSFT',
#   'Mar-21-22',
#   '10:18AM',
#   'Russias Invasion Is\xa0Accelerating Splinternet, French Envoy Says'],
#  ['MSFT',
#   'Mar-21-22',
#   '09:26AM',
#   '10 Tech Stocks to Buy According Billionaire Chase Coleman'],
#  ['MSFT',
#   'Mar-21-22',
#   '09:24AM',
#   "Does Sony Finally Have Its Answer to Microsoft's Gaming Buying Spree?"],
#  ['MSFT',
#   'Mar-21-22',
#   '08:36AM',
#   'Baron Funds: Microsoft (MSFT) is Positioned to Deliver 13%-15% Organic Growth Over the Next 3 Years'],
#  ['MSFT',
#   'Mar-21-22',
#   '08:13AM',
#   'Dow Jones Futures: What To Do After Four Market Days That Changed Everything'],
#  ['MSFT',
#   'Mar-21-22',
#   '07:50AM',
#   'Software Growth Stocks To Buy, Watch Or Sell Amid Nasdaq Volatility'],
#  ['MSFT',
#   'Mar-21-22',
#   '07:35AM',
#   'Is Snowflake Stock A Buy Or Sell Amid Software Sector Volatility?'],
#  ['MSFT',
#   'Mar-21-22',
#   '07:25AM',
#   'Is Salesforce Stock A Buy? Earnings Beat Amid Pull-Back In Software Growth Stocks'],
#  ['MSFT',
#   'Mar-21-22',
#   '06:51AM',
#   'Microsoft Bings autocomplete function has been mysteriously banned in China'],
#  ['MSFT',
#   'Mar-21-22',
#   '06:20AM',
#   'Should WisdomTree U.S. Total Dividend ETF (DTD) Be on Your Investing Radar?'],
#  ['MSFT',
#   'Mar-21-22',
#   '06:20AM',
#   'Should SPDR Portfolio S&P 500 ETF (SPLG) Be on Your Investing Radar?'],
#  ['MSFT',
#   'Mar-21-22',
#   '06:20AM',
#   'Is WisdomTree U.S. LargeCap Dividend ETF (DLN) a Strong ETF Right Now?'],
#  ['MSFT',
#   'Mar-21-22',
#   '06:01AM',
#   "The stock market is depressed, and apparently that's great"],
#  ['MSFT',
#   'Mar-21-22',
#   '05:00AM',
#   'Get Microsoft Office Home & Business For Mac For A Great Price'],
#  ['MSFT',
#   'Mar-21-22',
#   '12:22AM',
#   "China requires Microsoft's Bing to suspend auto-suggest feature"],
#  ['MSFT',
#   'Mar-21-22',
#   '12:19AM',
#   "China requires Microsoft's Bing to suspend auto-suggest feature"],
#  ['MSFT',
#   'Mar-20-22',
#   '12:42PM',
#   'Why You Should Buy Cybersecurity Stocks & ETFs Now'],
#  ['MSFT', 'Mar-19-22', '05:12PM', 'The Importance of Excel in Business'],
#  ['MSFT',
#   'Mar-19-22',
#   '02:49PM',
#   'Dow Jones Futures: Four Market Days That Changed Everything; What To Do Now'],
#  ['MSFT',
#   'Mar-19-22',
#   '10:21AM',
#   '10 Stocks Under $30 In Ken Fishers Portfolio'],
#  ['MSFT',
#   'Mar-18-22',
#   '03:18PM',
#   'Stocks turn positive to end the week, led by megacap sectors'],
#  ['MSFT',
#   'Mar-18-22',
#   '02:38PM',
#   '3 Dividend Growth Stocks to Buy During This Market Correction'],
#  ['MSFT',
#   'Mar-18-22',
#   '01:30PM',
#   "Why Microsoft's Dividend Growth Is Still In the Early Innings"],
#  ['MSFT',
#   'Mar-18-22',
#   '11:14AM',
#   'Thinking about trading options or stock in NVIDIA, Alibaba, Microsoft, Exxon Mobil, or Cisco Systems?'],
#  ['MSFT',
#   'Mar-18-22',
#   '10:20AM',
#   'Microsoft Ads in Windows Could Drive Product Adoption'],
#  ['MSFT',
#   'Mar-18-22',
#   '09:10AM',
#   'Rogers Communications (RCI)-Microsoft Inks Deal, Focus on Digitization'],
#  ['MSFT',
#   'Mar-17-22',
#   '08:01PM',
#   'Top investment tips for a stocks and shares ISA'],
#  ['MSFT', 'Mar-17-22', '07:51PM', '10 Reddit Stocks to Buy in March'],
#  ['MSFT',
#   'Mar-17-22',
#   '04:12PM',
#   'Why You Should Buy Cybersecurity Stocks & ETFs Now'],
#  ['MSFT',
#   'Mar-17-22',
#   '04:06PM',
#   'Russia-Ukraine war keeps me away from going all-in on tech stocks, portfolio manager says'],
#  ['MSFT',
#   'Mar-17-22',
#   '03:24PM',
#   'Stocks turn higher, oil has biggest day since November 2020'],
#  ['MSFT',
#   'Mar-17-22',
#   '01:13PM',
#   'Buy oversold tech stocks, especially Apple: Analyst'],
#  ['MSFT',
#   'Mar-17-22',
#   '12:00PM',
#   'Ransomware Hackers Used AI Images, Microsoft Flaw in Campaign'],
#  ['MSFT',
#   'Mar-17-22',
#   '11:38AM',
#   'Microsoft data centres to heat Finnish homes, cutting emissions'],
#  ['MSFT',
#   'Mar-17-22',
#   '10:46AM',
#   'Market strategist talks stocks, investing amid rising rates, and the metaverse ETF'],
#  ['MSFT',
#   'Mar-17-22',
#   '09:00AM',
#   'Apple and\xa0Google Are Brawling With Peers Over Future of the App Store'],
#  ['MSFT',
#   'Mar-17-22',
#   '08:12AM',
#   '3 Growth Stocks That Could Be Headed for Trouble'],
#  ['MSFT',
#   'Mar-17-22',
#   '07:15AM',
#   'Microsoft faces EU antitrust complaint about its cloud computing business'],
#  ['MSFT',
#   'Mar-17-22',
#   '07:10AM',
#   'Why Microsoft Has an Edge Over Facebook in the Metaverse'],
#  ['MSFT',
#   'Mar-17-22',
#   '06:20AM',
#   'Should Invesco S&P 500 Top 50 ETF (XLG) Be on Your Investing Radar?'],
#  ['MSFT',
#   'Mar-16-22',
#   '06:30PM',
#   "Value Investors Shouldn't Be Scared Off by War"],
#  ['MSFT',
#   'Mar-16-22',
#   '04:05PM',
#   'Box Forecasts\xa0Annual Sales\xa0Growth of Up to\xa017% in 2025'],
#  ['MSFT',
#   'Mar-16-22',
#   '01:51PM',
#   'Microsoft accidentally promotes fake Amazon website pushing an Elon Musk bitcoin scam'],
#  ['MSFT',
#   'Mar-16-22',
#   '01:10PM',
#   'Rogers and Microsoft announce strategic alliance to revolutionize hybrid workplace communications and power 5G innovation across Canada with Azure'],
#  ['MSFT',
#   'Mar-16-22',
#   '12:31PM',
#   'Rogers and Microsoft announce strategic alliance to revolutionize hybrid workplace communications and power 5G innovation across Canada with Azure'],
#  ['MSFT',
#   'Mar-16-22',
#   '12:01PM',
#   'MongoDB (MDB) Expands Multi-Year Partnership With AWS'],
#  ['MSFT',
#   'Mar-16-22',
#   '09:46AM',
#   "Russia-Ukraine war: Financial sector 'on high alert' for cyberattacks, Crowdstrike CEO says"],
#  ['MSFT',
#   'Mar-16-22',
#   '09:21AM',
#   '10 Penny Stocks with Upcoming Growth Catalysts'],
#  ['MSFT',
#   'Mar-16-22',
#   '09:21AM',
#   'Rajiv Jains GQG Partners Portfolio: 10 Dividend Stock Picks'],
#  ['METV',
#   'Mar-23-22',
#   '02:52PM',
#   'Metaverse presents half a trillion-dollar opportunity: ProShares strategist'],
#  ['METV',
#   'Mar-22-22',
#   '12:00AM',
#   'Roundhill Ball Metaverse UCITS ETF (METV) Launches in Germany'],
#  ['METV', 'Mar-17-22', '04:00AM', 'ProShares Launches Metaverse ETF'],
#  ['METV',
#   'Mar-11-22',
#   '03:30AM',
#   'Roundhill Investments to Launch Metaverse ETF in Germany'],
#  ['METV',
#   'Feb-07-22',
#   '09:00AM',
#   'Roundhill Ball Metaverse ETF Reduces Management Fee'],
#  ['METV',
#   'Feb-07-22',
#   '08:15AM',
#   'ETF Odds & Ends: 2022 Leads 2021 For Launches'],
#  ['METV',
#   'Feb-03-22',
#   '03:30PM',
#   "Newly Launched 'PUNK' Times Metas Meltdown"],
#  ['METV', 'Feb-02-22', '06:30PM', 'Metas Miss Reverberates Through ETFs'],
#  ['METV',
#   'Feb-02-22',
#   '12:39PM',
#   'Stocks in focus: Alphabet, Netflix, Meta, Amazon, Tesla'],
#  ['METV', 'Jan-28-22', '12:30PM', 'Timing Is Everything For ETFs'],
#  ['METV', 'Jan-14-22', '05:30PM', 'Roundhill Gives Up META Ticker']]

# %%
parsed_news[0]
# Out:
# ['FSLY',
#  'Mar-23-22',
#  '06:15PM',
#  'Fastly (FSLY) Stock Moves -0.98%: What You Should Know']

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\SiYu\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
# Instantiate the sentiment intensity analyzer
vader = SentimentIntensityAnalyzer()

# Set column names
columns = ['ticker', 'date', 'time', 'headline']

# Convert the parsed_news list into a DataFrame called 'parsed_and_scored_news'
parsed_and_scored_news = pd.DataFrame(parsed_news, columns=columns)

# Iterate through the headlines and get the polarity scores using vader
scores = parsed_and_scored_news['headline'].apply(vader.polarity_scores).tolist()

# Convert the 'scores' list of dicts into a DataFrame
scores_df = pd.DataFrame(scores)

# Join the DataFrames of the news and the list of dicts
parsed_and_scored_news = parsed_and_scored_news.join(scores_df, rsuffix='_right')

# Convert the date column from string to datetime
parsed_and_scored_news['date'] = pd.to_datetime(parsed_and_scored_news.date).dt.date

parsed_and_scored_news.head()
# Out:
#   ticker        date     time  \
# 0   FSLY  2022-03-23  06:15PM
# 1   FSLY  2022-03-23  02:23PM
# 2   FSLY  2022-03-22  08:01AM
# 3   FSLY  2022-03-21  10:58AM
# 4   FSLY  2022-03-21  05:06AM
#
#                                             headline    neg    neu    pos  \
# 0  Fastly (FSLY) Stock Moves -0.98%: What You Sho...  0.000  1.000  0.000
# 1  Fastly Only Vendor Named Gartner Peer Insights...  0.000  1.000  0.000
# 2  Cloudflare Doesnt Offer Investors Security at ...  0.225  0.775  0.000
# 3  Will Adobe's (ADBE) Q1 Earnings Gain From Digi...  0.000  0.702  0.298
# 4   10 Stocks I've Bought During the Market Sell-Off  0.000  1.000  0.000
#
#    compound
# 0    0.0000
# 1    0.0000
# 2   -0.2584
# 3    0.5267
# 4    0.0000

# %%
plt.rcParams['figure.figsize'] = [10, 6]

# Group by date and ticker columns from scored_news and calculate the mean
mean_scores = parsed_and_scored_news.groupby(['ticker','date']).mean()

# Unstack the column ticker
mean_scores = mean_scores.unstack()

# Get the cross-section of compound in the 'columns' axis
mean_scores = mean_scores.xs('compound', axis="columns").transpose()

# Plot a bar chart with pandas
mean_scores.plot(kind = 'bar')
plt.grid()

# %%
FSLY_sentiment=parsed_and_scored_news[parsed_and_scored_news["ticker"]=="FSLY"]
FSLY_sentiment
# Out:
#    ticker        date     time  \
# 0    FSLY  2022-03-23  06:15PM
# 1    FSLY  2022-03-23  02:23PM
# 2    FSLY  2022-03-22  08:01AM
# 3    FSLY  2022-03-21  10:58AM
# 4    FSLY  2022-03-21  05:06AM
# ..    ...         ...      ...
# 95   FSLY  2021-11-29  05:05PM
# 96   FSLY  2021-11-29  09:00AM
# 97   FSLY  2021-11-19  09:47AM
# 98   FSLY  2021-11-18  07:09AM
# 99   FSLY  2021-11-17  08:40AM
#
#                                              headline    neg    neu    pos  \
# 0   Fastly (FSLY) Stock Moves -0.98%: What You Sho...  0.000  1.000  0.000
# 1   Fastly Only Vendor Named Gartner Peer Insights...  0.000  1.000  0.000
# 2   Cloudflare Doesnt Offer Investors Security at ...  0.225  0.775  0.000
# 3   Will Adobe's (ADBE) Q1 Earnings Gain From Digi...  0.000  0.702  0.298
# 4    10 Stocks I've Bought During the Market Sell-Off  0.000  1.000  0.000
# ..                                                ...    ...    ...    ...
# 95             Why Fastly Stock Rose Higher on Monday  0.000  1.000  0.000
# 96  Fastly Names Lakshmi Sharma as New Chief Produ...  0.000  1.000  0.000
# 97  10 New Stock Picks of Billionaire Stanley Druc...  0.000  1.000  0.000
# 98      When Should You Buy Fastly, Inc. (NYSE:FSLY)?  0.000  1.000  0.000
# 99     Fastly Q3 Earnings: What Investors Should Know  0.000  1.000  0.000
#
#     compound
# 0     0.0000
# 1     0.0000
# 2    -0.2584
# 3     0.5267
# 4     0.0000
# ..       ...
# 95    0.0000
# 96    0.0000
# 97    0.0000
# 98    0.0000
# 99    0.0000
#
# [100 rows x 8 columns]

# %%
FSLY_sentiment.plot(x="date",y="compound")
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# # Calculation MACD

# %%
TechIndicator = copy.deepcopy(data)

# %%
MACD=TechIndicator["Close"]
MACD
# Out:
# Symbols          FSLY  IMMR          FB           U        NVDA        AAPL  \
# Date
# 2021-06-30  59.599998  8.77  347.709991  109.830002  200.024994  136.960007
# 2021-07-01  58.020000  8.49  354.390015  105.839996  202.119995  137.270004
# 2021-07-02  56.470001  8.46  354.700012  106.089996  204.869995  139.960007
# 2021-07-06  56.860001  8.22  352.779999  106.650002  206.985001  142.020004
# 2021-07-07  54.369999  8.23  350.489990  104.489998  203.717499  144.570007
# ...               ...   ...         ...         ...         ...         ...
# 2021-12-27  37.750000  6.05  346.179993  148.009995  309.450012  180.330002
# 2021-12-28  36.259998  5.87  346.220001  143.520004  303.220001  179.289993
# 2021-12-29  35.090000  5.80  342.940002  144.550003  300.010010  179.380005
# 2021-12-30  37.230000  5.85  344.359985  145.919998  295.859985  178.199997
# 2021-12-31  35.450001  5.71  336.350006  142.990005  294.109985  177.570007
#
# Symbols           MSFT   METV
# Date
# 2021-06-30  270.899994  15.12
# 2021-07-01  271.600006  14.89
# 2021-07-02  277.649994  15.00
# 2021-07-06  277.660004  15.01
# 2021-07-07  279.929993  14.89
# ...                ...    ...
# 2021-12-27  342.450012  15.60
# 2021-12-28  341.250000  15.37
# 2021-12-29  341.950012  15.25
# 2021-12-30  339.320007  15.31
# 2021-12-31  336.320007  15.18
#
# [129 rows x 8 columns]

# %%
def calculate_MACD(stock):
    df=MACD[stock].to_frame()
    df["long_term_EMA"]=df[stock].ewm(span=26,adjust=False).mean() #long term EMA 
    df["short_term_EMA"]=df[stock].ewm(span=12,adjust=False).mean() #short term EMA 
    df["MACD"]=df["short_term_EMA"]-df["long_term_EMA"]           #MACD line
    df["Signal_line"]=df["MACD"].ewm(span=9,adjust=False).mean() # Signal line 
        
    return(df)

# %%
stock="AAPL"
df=calculate_MACD(stock)

plt.style.use('fivethirtyeight')
plt.figure(figsize=(12.2,4.5))
plt.plot(df.index,df["MACD"],label=stock+" MACD",color="red")
plt.plot(df.index,df["Signal_line"],label=stock+" Signal_line",color="blue")
plt.legend(loc="upper left")
plt.show()

# %%
df["AAPL"]
# Out:
# Date
# 2021-06-30    136.960007
# 2021-07-01    137.270004
# 2021-07-02    139.960007
# 2021-07-06    142.020004
# 2021-07-07    144.570007
#                  ...
# 2021-12-27    180.330002
# 2021-12-28    179.289993
# 2021-12-29    179.380005
# 2021-12-30    178.199997
# 2021-12-31    177.570007
# Name: AAPL, Length: 129, dtype: float64

# %%
def buy_sell(signal):
    Buy=[]
    Sell=[]
    flag= -1 
    
    
    for i in range(0,len(signal)):
        if signal["MACD"][i] > signal["Signal_line"][i]:
            Sell.append(np.nan)
            if flag != 1 :
                Buy.append(signal[stock][i])
                flag=1 
            else:
                Buy.append(np.nan)
        
        elif signal["MACD"][i] < signal["Signal_line"][i]:
            Buy.append(np.nan)
            if flag != 0 :
                Sell.append(signal[stock][i])
                flag= 0
            else:
                Sell.append(np.nan)
        else:
            Buy.append(np.nan)
            Sell.append(np.nan)
    return (Buy,Sell)

# %%
a=buy_sell(df)
df['Buy_Signal_Price']=a[0]
df["Sell_Signal_Price"]=a[1]
df
# Out:
#                   AAPL  long_term_EMA  short_term_EMA      MACD  Signal_line  \
# Date
# 2021-06-30  136.960007     136.960007      136.960007  0.000000     0.000000
# 2021-07-01  137.270004     136.982969      137.007699  0.024729     0.004946
# 2021-07-02  139.960007     137.203491      137.461900  0.258409     0.055638
# 2021-07-06  142.020004     137.560270      138.163147  0.602877     0.165086
# 2021-07-07  144.570007     138.079509      139.148818  1.069308     0.345931
# ...                ...            ...             ...       ...          ...
# 2021-12-27  180.330002     168.900592      173.951370  5.050778     5.173864
# 2021-12-28  179.289993     169.670178      174.772697  5.102519     5.159595
# 2021-12-29  179.380005     170.389424      175.481514  5.092090     5.146094
# 2021-12-30  178.199997     170.967985      175.899742  4.931757     5.103226
# 2021-12-31  177.570007     171.457024      176.156706  4.699682     5.022518
#
#             Buy_Signal_Price  Sell_Signal_Price
# Date
# 2021-06-30               NaN                NaN
# 2021-07-01        137.270004                NaN
# 2021-07-02               NaN                NaN
# 2021-07-06               NaN                NaN
# 2021-07-07               NaN                NaN
# ...                      ...                ...
# 2021-12-27               NaN                NaN
# 2021-12-28               NaN                NaN
# 2021-12-29               NaN                NaN
# 2021-12-30               NaN                NaN
# 2021-12-31               NaN                NaN
#
# [129 rows x 7 columns]

# %%
plt.figure(figsize=(12.2,4.5))
plt.scatter(df.index,df["Buy_Signal_Price"],color="green",label="Buy",marker="^",alpha=1)
plt.scatter(df.index,df["Sell_Signal_Price"],color="red",label="Sell",marker="v",alpha=1)
plt.plot(df[stock],label="Close Price",alpha=0.35)
plt.title("Close Price Buy & Sell Signals")
plt.xlabel("Date")
plt.ylabel("Close Price in USD")
plt.show()
